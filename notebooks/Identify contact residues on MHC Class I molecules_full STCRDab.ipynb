# %% [markdown]
# # Introduction
#
# This an extension of the notebook that does this analysis on the smaller *apo* and *holo* dataset.
#
# Goals:
#
# * Identify IMGT residue positions that make contact with the TCR
#   * See what loops those correspond to on the TCR side of things

# %%
import glob
import os
import itertools
from collections import OrderedDict, defaultdict

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

from python_pdb.parsers import parse_pdb_to_pandas
from tcr_structure_tools.cdr_numbering import assign_cdr_number

# %%
STCRDAB_PATH = '/project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10'

# %%
stcrdab_summary = pd.read_csv(os.path.join(STCRDAB_PATH, 'db_summary.dat'), delimiter='\t')

selected_stcrdab = stcrdab_summary.copy()

# Resolution better than 3.50 Å
selected_stcrdab['resolution'] = pd.to_numeric(selected_stcrdab['resolution'], errors='coerce')
selected_stcrdab = selected_stcrdab.query("resolution < 3.50")

# alpha-beta TCRs
selected_stcrdab = selected_stcrdab.query("TCRtype == 'abTCR'")

# MHC class I
selected_stcrdab = selected_stcrdab.query("mhc_type == 'MH1'")

# peptide antigen
selected_stcrdab = selected_stcrdab.query("antigen_type == 'peptide'")

# General clean: drop columns that don't contain anything useful
selected_stcrdab = selected_stcrdab.loc[:, selected_stcrdab.nunique() > 1]
selected_stcrdab = selected_stcrdab.dropna(axis=1, how='all')

# Reset Index
selected_stcrdab = selected_stcrdab.reset_index(drop=True)

selected_stcrdab
# Out:
#       pdb Bchain Achain antigen_chain  \
# 0    7rk7      E      D             C
# 1    2ak4      E      D             C
# 2    7nme      E      D             C
# 3    7pbe      J      I             H
# 4    5wkh      J      I             H
# ..    ...    ...    ...           ...
# 280  3mv9      E      D             C
# 281  6q3s      E      D             C
# 282  5men      E      D             C
# 283  3vxu      J      I             H
# 284  4jff      E      D             C
#
#                                          antigen_name mhc_chain1 mhc_chain2  \
# 0                                  tyrosinase peptide          A          B
# 1                           ebv peptide lpeplpqgqltay          A          B
# 2                 gln-leu-pro-arg-leu-phe-pro-leu-leu          A          B
# 3                                    spike protein s1          F          G
# 4                                        gts3 peptide          F          G
# ..                                                ...        ...        ...
# 280  hpvg peptide from epstein-barr nuclear antigen 1          A          B
# 281               ser-leu-leu-met-trp-ile-thr-gln-val          A          B
# 282               ile-leu-ala-lys-phe-leu-his-trp-leu          A          B
# 283                   10-mer peptide from protein nef          F          G
# 284                                    melanoma motif          A          B
#
#      docking_angle beta_subgroup alpha_subgroup  ... alpha_organism  \
# 0           81.339        TRBV10          TRAV4  ...   homo sapiens
# 1           71.108         TRBV6         TRAV19  ...   homo sapiens
# 2           36.100         TRBV7          TRAV5  ...   homo sapiens
# 3           49.843         TRBV7         TRAV12  ...   homo sapiens
# 4           39.564        TRBV11         TRAV30  ...   homo sapiens
# ..             ...           ...            ...  ...            ...
# 280         41.382         TRBV9         TRAV20  ...   homo sapiens
# 281         67.059         TRBV6         TRAV21  ...   homo sapiens
# 282         40.823         TRBV6         TRAV22  ...   homo sapiens
# 283            NaN        TRBV27         TRAV12  ...   homo sapiens
# 284         42.977        TRBV30         TRAV12  ...   homo sapiens
#
#                                     antigen_organism mhc_chain1_organism  \
# 0                                       homo sapiens        homo sapiens
# 1                                                NaN        homo sapiens
# 2                                       homo sapiens        homo sapiens
# 3    severe acute respiratory syndrome coronavirus2         homo sapiens
# 4                                     dengue virus 3        homo sapiens
# ..                                               ...                 ...
# 280                                              NaN        homo sapiens
# 281                                     homo sapiens        homo sapiens
# 282                                     homo sapiens        homo sapiens
# 283                   human immunodeficiency virus 1        homo sapiens
# 284                                     homo sapiens        homo sapiens
#
#     mhc_chain2_organism                                            authors  \
# 0          homo sapiens  Singh, N.K., Davancaze, L.M., Arbuiso, A., Wei...
# 1          homo sapiens  Tynan, F.E., Burrows, S.R., Buckle, A.M., Clem...
# 2          homo sapiens  Rizkallah, P.J., Sewell, A.K., Cole, D.K., Wal...
# 3          homo sapiens  Rizkallah, P.J., Sewell, A.K., Wall, A., Fulle...
# 4          homo sapiens                             Gras, S., Rossjohn, J.
# ..                  ...                                                ...
# 280        homo sapiens  Gras, S., Chen, Z., Miles, J.J., Liu, Y.C., Be...
# 281        homo sapiens  Meijers, R., Anjanappa, R., Springer, S., Garc...
# 282        homo sapiens  Rizkallah, P.J., Lloyd, A., Crowther, M., Cole...
# 283        homo sapiens  Shimizu, A., Fukai, S., Yamagata, A., Iwamoto, A.
# 284        homo sapiens  Rizkallah, P.J., Cole, D.K., Madura, F., Sewel...
#
#     resolution             method r_free r_factor  engineered
# 0         2.54  X-RAY DIFFRACTION  0.255    0.211        True
# 1         2.50  X-RAY DIFFRACTION  0.278    0.246        True
# 2         2.20  X-RAY DIFFRACTION  0.274    0.215        True
# 3         3.00  X-RAY DIFFRACTION  0.296    0.228        True
# 4         3.20  X-RAY DIFFRACTION  0.246    0.177        True
# ..         ...                ...    ...      ...         ...
# 280       2.70  X-RAY DIFFRACTION  0.331    0.234        True
# 281       2.50  X-RAY DIFFRACTION  0.273    0.229        True
# 282       2.81  X-RAY DIFFRACTION  0.272    0.189        True
# 283       2.70  X-RAY DIFFRACTION  0.323    0.272        True
# 284       2.43  X-RAY DIFFRACTION  0.263    0.210        True
#
# [285 rows x 24 columns]

# %%
CUTOFF_DISTANCE = 5

contacts = []

for _, row in selected_stcrdab.iterrows():
    path = os.path.join(STCRDAB_PATH, 'imgt', f'{row.pdb}.pdb')
    print(path)

    with open(path, 'r') as fh:
        df = parse_pdb_to_pandas(fh.read())
    
    chain_annotations = {}
    chain_annotations[row.Achain] = 'alpha_chain'
    chain_annotations[row.Bchain] = 'beta_chain'
    chain_annotations[row.antigen_chain] = 'antigen_chain'
    chain_annotations[row.mhc_chain1] = 'mhc_chain'
    
    df['chain_type'] = df['chain_id'].map(lambda id_: chain_annotations[id_] if id_ in chain_annotations else None)
    df['cdr'] = df['residue_seq_id'].map(assign_cdr_number)
    
    mhc_interface_df = df.query("chain_type == 'mhc_chain' and residue_seq_id < 1090")
    tcr_cdrs_df = df.query("(chain_type == 'alpha_chain' or chain_type == 'beta_chain') and cdr.notnull()") 
    
    interface = tcr_cdrs_df.merge(mhc_interface_df, how='cross', suffixes=('_tcr', '_mhc'))
    
    interface['distance'] = np.sqrt(np.square(interface['pos_x_tcr'] - interface['pos_x_mhc'])
                                    + np.square(interface['pos_y_tcr'] - interface['pos_y_mhc'])
                                    + np.square(interface['pos_z_tcr'] - interface['pos_z_mhc']))

    c = interface.query('distance < @CUTOFF_DISTANCE').copy()
    c['path'] = path
    
    contacts.append(c)

contacts = pd.concat(contacts)
contacts
# Out:
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/7rk7.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/2ak4.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/7nme.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/7pbe.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/5wkh.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/3w0w.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/5w1v.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/7rtr.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/2nx5.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/5nht.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/3tpu.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/2p5e.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/5jzi.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/3tpu.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/6am5.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/2ak4.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/3e3q.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/3mv8.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/3kpr.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/5hyj.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/1kj2.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/6rpb.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/3pqy.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/5xov.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/3uts.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/6avg.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/7rm4.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/3pwp.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/5w1v.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/7n6e.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/3d39.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/6rp9.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/4mji.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/5swz.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/7jwj.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/6vmx.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/5til.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/2f53.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/3qdj.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/7pbe.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/6bj2.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/3qdm.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/6avf.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/5c07.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/3vxu.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/3tpu.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/6vqo.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/2p5w.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/3utt.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/6zkz.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/6avg.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/6tmo.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/5wkf.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/5d2n.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/6mtm.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/4eup.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/5ivx.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/2f54.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/5bs0.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/5m00.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/7rm4.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/6eqb.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/6l9l.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/5tje.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/2j8u.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/1lp9.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/3kps.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/3tf7.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/2bnr.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/7ow5.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/3kpr.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/6rpb.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/1nam.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/3pqy.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/5c09.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/4mxq.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/4prh.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/5jzi.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/1qrn.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/3kxf.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/2bnq.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/5c0a.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/3kxf.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/5wkf.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/3e3q.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/2nx5.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/1g6r.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/8gvb.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/7rm4.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/5wlg.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/5nmg.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/7byd.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/5hho.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/1qse.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/5hyj.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/3sjv.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/5xov.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/2ypl.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/3rgv.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/5w1v.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/1g6r.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/5m01.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/5swz.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/8gvi.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/7n5c.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/7rm4.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/3pqy.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/2e7l.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/2ol3.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/6bj8.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/7qpj.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/3vxm.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/7byd.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/6eqa.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/6bj3.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/1qsf.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/4mji.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/1oga.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/3qdg.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/7na5.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/5c07.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/4pri.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/7dzm.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/5m02.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/2ckb.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/3tfk.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/3sjv.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/4qok.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/2uwe.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/5c08.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/3hg1.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/5jhd.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/3e3q.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/4mnq.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/7dzn.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/6rpb.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/7n1e.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/3qeq.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/5c0a.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/5tje.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/3e3q.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/5w1w.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/2vlj.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/5xot.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/3vxr.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/4eup.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/7nmg.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/3d3v.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/5isz.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/2vlr.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/2f54.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/6rsy.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/4mvb.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/1mi5.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/5swz.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/3vxs.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/5w1w.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/8gvg.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/4qrr.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/2vlk.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/3sjv.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/3tpu.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/3uts.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/5hhm.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/3sjv.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/3e3q.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/4n0c.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/5c0b.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/7pb2.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/5til.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/4qrp.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/6rpa.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/2e7l.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/7n5p.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/7n1f.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/5c0c.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/6d78.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/6uz1.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/6vrm.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/3e3q.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/4n5e.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/7jwi.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/4jrx.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/7nmf.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/6zkx.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/4ms8.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/2ak4.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/5c09.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/5yxu.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/2nx5.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/4l3e.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/3o4l.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/5nme.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/5d2n.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/2jcc.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/5euo.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/6g9q.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/5c0b.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/6vmx.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/3tf7.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/6dkp.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/6l9l.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/5nqk.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/2pye.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/2jcc.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/6r2l.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/2oi9.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/3kxf.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/5wlg.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/3pqy.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/1lp9.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/3mv7.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/3e3q.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/5wkh.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/6rp9.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/5e9d.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/7n6e.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/2ak4.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/5nmg.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/5w1w.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/6amu.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/6rsy.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/5brz.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/5eu6.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/3tjh.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/3h9s.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/1mwa.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/4prp.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/1kj2.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/5nmf.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/3e3q.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/3utt.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/5w1v.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/1mwa.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/2vlr.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/4n0c.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/3kxf.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/5c08.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/1ao7.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/5swz.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/4g9f.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/5tez.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/4qrp.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/6zkw.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/4ftv.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/7pb2.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/2nx5.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/2ckb.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/6vrn.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/2esv.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/5hhm.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/4jfd.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/6zky.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/5jhd.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/5nmf.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/6tro.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/6vqo.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/7r80.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/6rpb.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/1bd2.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/7phr.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/3ffc.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/4jry.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/5sws.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/3ffc.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/5yxn.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/1fo0.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/3qfj.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/2j8u.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/3gsn.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/5c0c.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/2uwe.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/5w1w.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/5e9d.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/6uz1.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/7ow6.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/5euo.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/4g8g.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/5nme.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/4jfe.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/3mv9.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/6q3s.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/5men.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/3vxu.pdb
# /project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10/imgt/4jff.pdb
#        record_type_tcr  atom_number_tcr atom_name_tcr alt_loc_tcr  \
# 46127             ATOM              287            CB        None
# 47594             ATOM              288            CG        None
# 47595             ATOM              288            CG        None
# 47596             ATOM              288            CG        None
# 47624             ATOM              288            CG        None
# ...                ...              ...           ...         ...
# 464737            ATOM             2840           NH1        None
# 466203            ATOM             2841           NH2        None
# 466204            ATOM             2841           NH2        None
# 466205            ATOM             2841           NH2        None
# 466206            ATOM             2841           NH2        None
#
#        residue_name_tcr chain_id_tcr  residue_seq_id_tcr  \
# 46127               ARG            E                  37
# 47594               ARG            E                  37
# 47595               ARG            E                  37
# 47596               ARG            E                  37
# 47624               ARG            E                  37
# ...                 ...          ...                 ...
# 464737              ARG            D                 115
# 466203              ARG            D                 115
# 466204              ARG            D                 115
# 466205              ARG            D                 115
# 466206              ARG            D                 115
#
#        residue_insert_code_tcr  pos_x_tcr  pos_y_tcr  ...  pos_y_mhc  \
# 46127                     None     -9.824    -28.688  ...    -29.354
# 47594                     None     -8.601    -27.785  ...    -29.437
# 47595                     None     -8.601    -27.785  ...    -28.442
# 47596                     None     -8.601    -27.785  ...    -29.354
# 47624                     None     -8.601    -27.785  ...    -26.516
# ...                        ...        ...        ...  ...        ...
# 464737                    None     34.196     -6.464  ...     -8.470
# 466203                    None     34.779     -7.728  ...     -6.880
# 466204                    None     34.779     -7.728  ...     -7.968
# 466205                    None     34.779     -7.728  ...     -8.550
# 466206                    None     34.779     -7.728  ...     -8.470
#
#         pos_z_mhc  occupancy_mhc b_factor_mhc element_mhc charge_mhc  \
# 46127     -28.052            1.0        85.56           N       None
# 47594     -29.377            1.0        99.22           C       None
# 47595     -30.105            1.0       111.19           O       None
# 47596     -28.052            1.0        85.56           N       None
# 47624     -28.687            1.0        71.32           N       None
# ...           ...            ...          ...         ...        ...
# 464737     29.866            1.0        31.69           N       None
# 466203     28.238            1.0        29.24           N       None
# 466204     28.670            1.0        30.85           C       None
# 466205     27.915            1.0        33.82           N       None
# 466206     29.866            1.0        31.69           N       None
#
#         chain_type_mhc cdr_mhc  distance  \
# 46127        mhc_chain     NaN  4.994149
# 47594        mhc_chain     NaN  4.284034
# 47595        mhc_chain     NaN  4.269574
# 47596        mhc_chain     NaN  4.041411
# 47624        mhc_chain     NaN  4.397017
# ...                ...     ...       ...
# 464737       mhc_chain     2.0  4.581176
# 466203       mhc_chain     2.0  4.852275
# 466204       mhc_chain     2.0  4.029620
# 466205       mhc_chain     2.0  3.997626
# 466206       mhc_chain     2.0  3.781571
#
#                                                      path
# 46127   /project/koohylab/shared/tcr_data/raw_DONOTMOD...
# 47594   /project/koohylab/shared/tcr_data/raw_DONOTMOD...
# 47595   /project/koohylab/shared/tcr_data/raw_DONOTMOD...
# 47596   /project/koohylab/shared/tcr_data/raw_DONOTMOD...
# 47624   /project/koohylab/shared/tcr_data/raw_DONOTMOD...
# ...                                                   ...
# 464737  /project/koohylab/shared/tcr_data/raw_DONOTMOD...
# 466203  /project/koohylab/shared/tcr_data/raw_DONOTMOD...
# 466204  /project/koohylab/shared/tcr_data/raw_DONOTMOD...
# 466205  /project/koohylab/shared/tcr_data/raw_DONOTMOD...
# 466206  /project/koohylab/shared/tcr_data/raw_DONOTMOD...
#
# [87920 rows x 36 columns]

# %%
contacts['pdb_id'] = contacts['path'].map(lambda path: path.split('/')[-1].split('.')[0])

# %%
contacts['resi_mhc'] = contacts['residue_seq_id_mhc'].apply(str) + contacts['residue_insert_code_mhc'].fillna('')
contacts['resi_tcr'] = contacts['residue_seq_id_tcr'].apply(str) + contacts['residue_insert_code_tcr'].fillna('')

# %%
contacts['cdr_name'] = 'CDR' \
    + contacts['cdr_tcr'].apply(int).apply(str) \
    + contacts['chain_type_tcr'].map(lambda chain_type: chain_type.split('_')[0])

# %%
plt.figure(figsize=(12, 10))

sns.histplot(contacts.sort_values('residue_seq_id_mhc'), x='resi_mhc', hue='cdr_name', multiple='stack')
plt.xticks(rotation=90)
plt.grid()
print()
# Out:
# /package/python-cbrg/current/3.11/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
mhc_labels = contacts[['residue_seq_id_mhc', 'residue_insert_code_mhc', 'resi_mhc']].fillna('').sort_values(['residue_seq_id_mhc', 'residue_insert_code_mhc'])['resi_mhc'].unique().tolist()
tcr_labels = contacts[['residue_seq_id_tcr', 'residue_insert_code_tcr', 'resi_tcr']].fillna('').sort_values(['residue_seq_id_tcr', 'residue_insert_code_tcr'])['resi_tcr'].unique().tolist()

contacts['resi_mhc'] = pd.Categorical(contacts['resi_mhc'], mhc_labels)
contacts['resi_tcr'] = pd.Categorical(contacts['resi_tcr'], tcr_labels)

# %%
contacts['colour'] = contacts['cdr_name'].map({
    'CDR1alpha': 'DC91BE',
    'CDR2alpha': 'C0C0C2',
    'CDR3alpha': '6490C7',
    'CDR1beta': '963E87',
    'CDR2beta': '636363',
    'CDR3beta': '56BBD3',
}).str.lower()

# %%
palette = ['#' + colour.lower() for colour in ['DC91BE','C0C0C2', '6490C7', '963E87','2D2E62','56BBD3']]

# %%
contacts['cdr_name'] = pd.Categorical(contacts['cdr_name'], ['CDR1alpha', 'CDR2alpha', 'CDR3alpha', 'CDR1beta', 'CDR2beta', 'CDR3beta'])

# %%
plt.figure(figsize=(12, 10))

sns.histplot(contacts, x='resi_mhc', y='resi_tcr', hue='cdr_name', palette=sns.color_palette(palette, 6))
plt.xticks(rotation=90)
print()
# Out:
# /package/python-cbrg/current/3.11/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /package/python-cbrg/current/3.11/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /package/python-cbrg/current/3.11/lib/python3.11/site-packages/seaborn/_oldcore.py:1057: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_data = data.groupby(
