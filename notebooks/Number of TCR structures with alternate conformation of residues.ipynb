# %%
import os
import warnings

import pandas as pd
from python_pdb.entities import Structure
from python_pdb.parsers import parse_pdb

STCRDAB_PATH = '/project/koohylab/shared/tcr_data/raw_DONOTMODIFY/structure/STCRDab_all_2022-11-10'

# %%
stcrdab_summary = pd.read_csv(os.path.join(STCRDAB_PATH, 'db_summary.dat'), delimiter='\t')
stcrdab_summary
# Out:
#       pdb Bchain Achain Dchain Gchain TCRtype  model antigen_chain
# 0    7rk7      E      D    NaN    NaN   abTCR      0             C  \
# 1    7s8i      B      A    NaN    NaN   abTCR      0           NaN
# 2    7s8j      B      A    NaN    NaN   abTCR      0           NaN
# 3    3qux      D      C    NaN    NaN   abTCR      0             A
# 4    2z31      B      A    NaN    NaN   abTCR      0             P
# ..    ...    ...    ...    ...    ...     ...    ...           ...
# 890  3rtq      D      C    NaN    NaN   abTCR      0             A
# 891  3dxa      O      N    NaN    NaN   abTCR      0             M
# 892  1d9k      B      A    NaN    NaN   abTCR      0             P
# 893  4gg6      H      G    NaN    NaN   abTCR      0             J
# 894  2apf      A    NaN    NaN    NaN     NaN      0           NaN
#
#     antigen_type                                       antigen_name  ...
# 0        peptide                                 tyrosinase peptide  ...  \
# 1            NaN                                                NaN  ...
# 2            NaN                                                NaN  ...
# 3         Hapten  N-[(3S,4S,5R)-4,5-DIHYDROXY-1-[(2R,3R,4R,5R,6R...  ...
# 4        peptide                 myelin basic protein (mbp)-peptide  ...
# ..           ...                                                ...  ...
# 890       Hapten  N-[(2S,3S,4R)-3,4-DIHYDROXY-1-{[(1S,2S,3R,4R,5...  ...
# 891      peptide                            ebv decapeptide epitope  ...
# 892      peptide                                 conalbumin peptide  ...
# 893      peptide                peptide from alpha/beta-gliadin mm1  ...
# 894          NaN                                                NaN  ...
#
#                                                authors resolution
# 0    Singh, N.K., Davancaze, L.M., Arbuiso, A., Wei...       2.54  \
# 1    Patskovsky, Y., Nyovanie, S., Patskovska, L., ...       1.66
# 2    Patskovska, L., Patskovsky, Y., Nyovanie, S., ...       1.92
# 3          Li, Y., Girardi, E., Yu, E.D., Zajonc, D.M.       2.91
# 4        Feng, D., Bond, C.J., Ely, L.K., Garcia, K.C.        2.7
# ..                                                 ...        ...
# 890                             Yu, E.D., Zajonc, D.M.        2.8
# 891  Archbold, J.K., Macdonald, W.A., Gras, S., Ros...        3.5
# 892  Reinherz, E.L., Tan, K., Tang, L., Kern, P., L...        3.2
# 893  Broughton, S.E., Theodossis, A., Petersen, J.,...        3.2
# 894  Cho, S., Swaminathan, C.P., Yang, J., Kerzic, ...        1.8
#
#                 method r_free  r_factor affinity affinity_method
# 0    X-RAY DIFFRACTION  0.255     0.211      NaN             NaN  \
# 1    X-RAY DIFFRACTION  0.216     0.167      NaN             NaN
# 2    X-RAY DIFFRACTION  0.213     0.168      NaN             NaN
# 3    X-RAY DIFFRACTION  0.252     0.208      NaN             NaN
# 4    X-RAY DIFFRACTION  0.287     0.235      NaN             NaN
# ..                 ...    ...       ...      ...             ...
# 890  X-RAY DIFFRACTION  0.268     0.227      NaN             NaN
# 891  X-RAY DIFFRACTION  0.330     0.286      NaN             NaN
# 892  X-RAY DIFFRACTION  0.293     0.247      NaN             NaN
# 893  X-RAY DIFFRACTION  0.285     0.246      NaN             NaN
# 894  X-RAY DIFFRACTION  0.263     0.197      NaN             NaN
#
#     affinity_temperature affinity_pmid engineered
# 0                    NaN           NaN       True
# 1                    NaN           NaN       True
# 2                    NaN           NaN       True
# 3                    NaN           NaN       True
# 4                    NaN           NaN       True
# ..                   ...           ...        ...
# 890                  NaN           NaN       True
# 891                  NaN           NaN       True
# 892                  NaN           NaN       True
# 893                  NaN           NaN       True
# 894                  NaN           NaN       True
#
# [895 rows x 39 columns]

# %%
stcrdab_summary['raw_path'] = stcrdab_summary['pdb'].map(lambda pdb_id: os.path.join(STCRDAB_PATH, 'raw', f'{pdb_id}.pdb'))

# %%
def identify_residues_with_alt_conf(struct):
    residues_with_alt_locs = []

    for model in struct:
        for chain in model:
            for residue in chain:
                alt_locs = set()

                for atom in residue:
                    if atom.alt_loc:
                        alt_locs.add(atom.alt_loc)

                if len(alt_locs) >= 2:
                    residues_with_alt_locs.append((model.serial_number, chain.name, residue))
    
    return len(residues_with_alt_locs) > 0

alternate_states_count = 0
total_count = 0

for index, stcrdab_entry in stcrdab_summary.iterrows():
    print(stcrdab_entry['pdb'])
    with open(stcrdab_entry['raw_path'], 'r') as fh:
            structure = parse_pdb(fh.read(), silent=True)
    
    structure_df = structure.to_pandas()
    tcr_chains = [chain 
                  for chain in [stcrdab_entry['Achain'], stcrdab_entry['Bchain'], stcrdab_entry['Gchain'], stcrdab_entry['Dchain']]
                  if not pd.isna(chain)]
    
    print(tcr_chains)
    tcr_df = structure_df[structure_df['chain_id'].isin(tcr_chains)]
    
    with warnings.catch_warnings():
        warnings.filterwarnings("ignore")
        tcr_structure = Structure.from_pandas(tcr_df)
    
    if identify_residues_with_alt_conf(tcr_structure):
        print("Found one!")
        alternate_states_count += 1
        
    total_count += 1

print(f'{alternate_states_count} out of {total_count} have alternate residue conformations.')
# Out:
# 7rk7
# ['D', 'E']
# 7s8i
# ['A', 'B']
# Found one!
# 7s8j
# ['A', 'B']
# Found one!
# 3qux
# ['C', 'D']
# 2z31
# ['A', 'B']
# 2ak4
# ['D', 'E']
# 7nme
# ['D', 'E']
# 4x6c
# ['G', 'H']
# 7pbe
# ['I', 'J']
# 4z7w
# ['E', 'F']
# 6v18
# ['D', 'E']
# 5wkh
# ['I', 'J']
# 6fr7
# ['A', 'B']
# Found one!
# 3o8x
# ['C', 'D']
# 7sg1
# ['I', 'J']
# 3w0w
# ['D', 'E']
# 5w1v
# ['S', 'T']
# 4x6d
# ['E', 'F']
# 7rtr
# ['D', 'E']
# Found one!
# 2nx5
# ['I', 'J']
# 5nht
# ['A', 'B']
# 6eh9
# ['A', 'B']
# Found one!
# 6ulr
# ['D', 'E']
# 4nqe
# ['G', 'H']
# Found one!
# 3tpu
# ['M', 'N']
# 1hxm
# ['H', 'G']
# 7rrg
# ['D', 'E']
# Found one!
# 2p5e
# ['D', 'E']
# Found one!
# 4p2o
# ['C', 'D']
# 2aq3
# ['G']
# 5jzi
# ['I', 'J']
# 3rug
# ['E', 'F']
# 3tpu
# ['C', 'D']
# 4pjg
# ['G', 'H']
# 2z35
# ['A', 'B']
# 4e41
# ['D', 'E']
# Found one!
# 6am5
# ['D', 'E']
# 1kb5
# ['A', 'B']
# 3e2h
# ['B', 'C']
# 6c68
# ['A', 'B']
# 4udu
# ['A', 'B']
# 6puj
# ['B', 'G']
# Found one!
# 2ak4
# ['I', 'J']
# 3e3q
# ['Z', 'a']
# 3mv8
# ['D', 'E']
# Found one!
# 6puc
# ['G', 'H']
# Found one!
# 5wjo
# ['C', 'D']
# Found one!
# 3kpr
# ['D', 'E']
# 6fr9
# ['A', 'B']
# Found one!
# 5hyj
# ['D', 'E']
# 5ks9
# ['G', 'H']
# 1kj2
# ['D', 'E']
# 6mja
# ['C', 'D']
# 6vth
# ['D', 'E']
# 6rpb
# ['D', 'E']
# 6uon
# ['I', 'J']
# 6ovn
# ['A', 'B']
# Found one!
# 1zgl
# ['M', 'P']
# 3pqy
# ['S', 'T']
# 5xov
# ['G', 'H']
# 3uts
# ['D', 'E']
# 6avg
# ['C', 'D']
# Found one!
# 6v15
# ['D', 'E']
# 1ktk
# ['E']
# 4lhu
# ['G', 'D']
# 4z7u
# ['G', 'H']
# 7rm4
# ['J', 'I']
# 6wl3
# ['F']
# 3pwp
# ['D', 'E']
# 5w1v
# ['N', 'O']
# 3owe
# ['E']
# 7n6e
# ['G', 'H']
# 2icw
# ['K', 'L']
# 3tyf
# ['A', 'B']
# 3d39
# ['D', 'E']
# 1zgl
# ['S', 'T']
# 3dxa
# ['D', 'E']
# 6pug
# ['D', 'E']
# Found one!
# 7llj
# ['B']
# 6rp9
# ['I', 'J']
# 4mji
# ['I', 'J']
# 3qh3
# ['C', 'D']
# Found one!
# 6v19
# ['D', 'E']
# 6uk2
# ['D', 'E']
# 5swz
# ['D', 'E']
# 7jwj
# ['D', 'E']
# 6rp9
# ['K', 'L']
# 7rym
# ['C', 'D']
# 6vmx
# ['D', 'E']
# 5til
# ['G', 'H']
# 7fjd
# ['m', 'n']
# 4p4k
# ['C', 'D']
# 4h1l
# ['I', 'J']
# 3qi9
# ['C', 'D']
# 3r8b
# ['L']
# 2f53
# ['D', 'E']
# Found one!
# 3qdj
# ['D', 'E']
# 6xcp
# ['D', 'E']
# Found one!
# 4x6d
# ['G', 'H']
# 6puh
# ['D', 'E']
# Found one!
# 5l2k
# ['D', 'E']
# 5d7l
# ['G', 'H']
# 7pbe
# ['D', 'E']
# 6wl3
# ['I']
# 6bj2
# ['D', 'E']
# 1sbb
# ['A']
# Found one!
# 6cw9
# ['C', 'D']
# 6puh
# ['B', 'G']
# Found one!
# 6wl4
# ['C']
# 4elk
# ['A', 'B']
# Found one!
# 3qdm
# ['D', 'E']
# Found one!
# 2nw2
# ['A', 'B']
# Found one!
# 6avf
# ['A', 'B']
# Found one!
# 6pvd
# ['D', 'E']
# Found one!
# 1l0x
# ['C']
# 4nqd
# ['G', 'H']
# Found one!
# 6mng
# ['A', 'B']
# 2aq3
# ['A']
# 4ozi
# ['G', 'H']
# 1ymm
# ['D', 'E']
# 6vmc
# ['D', 'E']
# 5c07
# ['D', 'E']
# Found one!
# 5d7i
# ['G', 'H']
# Found one!
# 3vxu
# ['D', 'E']
# 5iw1
# ['A', 'B']
# 3rev
# ['A', 'B']
# 3tpu
# ['A', 'B']
# 5u17
# ['B', 'G']
# Found one!
# 6vqo
# ['D', 'E']
# 1j8h
# ['D', 'E']
# 4grm
# ['A', 'B']
# 4g8e
# ['A', 'B']
# 2p5w
# ['D', 'E']
# Found one!
# 4ww2
# ['A', 'B']
# Found one!
# 3utt
# ['D', 'E']
# 6pvc
# ['E', 'F']
# Found one!
# 6mkd
# ['A', 'B']
# 6zkz
# ['D', 'E']
# 3arg
# ['C', 'D']
# 7amp
# ['A', 'B']
# 4wnq
# ['A', 'B']
# Found one!
# 6avg
# ['B', 'E']
# 4qrp
# ['K', 'L']
# Found one!
# 3byy
# ['A']
# 4pj7
# ['G', 'H']
# 6p64
# ['D', 'E']
# 6wl2
# ['C']
# 6tmo
# ['D', 'E']
# Found one!
# 6pum
# ['G', 'H']
# Found one!
# 4elm
# ['G', 'H']
# 3qiu
# ['C', 'D']
# 3bzd
# ['A']
# 4pj9
# ['C', 'D']
# Found one!
# 6c61
# ['A', 'B']
# 6w9u
# ['G', 'H']
# Found one!
# 5iw1
# ['C', 'D']
# 5wkf
# ['I', 'J']
# 4pjf
# ['G', 'H']
# 2axh
# ['A']
# 5d2n
# ['C', 'F']
# 3tvm
# ['C', 'D']
# Found one!
# 3mc0
# ['A']
# 2q86
# ['C', 'D']
# 3rdt
# ['A', 'B']
# 3huj
# ['G', 'H']
# Found one!
# 6vm9
# ['D', 'E']
# 5ksa
# ['C', 'D']
# Found one!
# 2cdf
# ['A', 'B']
# 6mtm
# ['D', 'E']
# 4eup
# ['I', 'J']
# 3ta3
# ['C', 'D']
# 3byt
# ['E']
# 4z7v
# ['E', 'F']
# 5ivx
# ['E', 'F']
# 4dzb
# ['A', 'B']
# Found one!
# 2f54
# ['D', 'E']
# 5bs0
# ['D', 'E']
# 4pj8
# ['C', 'D']
# 6cqr
# ['D', 'E']
# Found one!
# 5m00
# ['G', 'H']
# Found one!
# 7lli
# ['F']
# 6fuo
# ['A', 'B']
# Found one!
# 7rm4
# ['E', 'D']
# 4ei5
# ['C', 'D']
# 6eqb
# ['D', 'E']
# Found one!
# 7r7z
# ['A', 'B']
# 4gg6
# ['E', 'F']
# 3dx9
# ['C', 'D']
# Found one!
# 4p2r
# ['N', 'O']
# 4p2q
# ['I', 'J']
# 6l9l
# ['G', 'H']
# 4wo4
# ['C', 'D']
# Found one!
# 6uk4
# ['D', 'E']
# 5e6i
# ['P', 'Q']
# 4mng
# ['f', 'F']
# 7ea6
# ['D', 'E']
# 2vlm
# ['D', 'E']
# 5tje
# ['E', 'F']
# 6dfq
# ['A', 'B']
# Found one!
# 2j8u
# ['L', 'M']
# 4irs
# ['C', 'D']
# 3tf7
# ['k', 'K']
# 3ard
# ['C', 'D']
# 5u16
# ['G', 'H']
# Found one!
# 1lp9
# ['L', 'M']
# 1l0x
# ['A']
# 4gg8
# ['E', 'F']
# 3kps
# ['D', 'E']
# 3tf7
# ['c', 'C']
# 2bnr
# ['D', 'E']
# 7amr
# ['A', 'B']
# Found one!
# 7ow5
# ['D', 'E']
# Found one!
# 3kpr
# ['I', 'J']
# 6mj4
# ['C', 'D']
# Found one!
# 6rpb
# ['S', 'T']
# 1nfd
# ['C', 'D']
# 3owe
# ['I']
# 3qeu
# ['D', 'E']
# Found one!
# 4lfh
# ['G', 'D']
# Found one!
# 3q5y
# ['A']
# Found one!
# 1nam
# ['A', 'B']
# 6cql
# ['D', 'E']
# Found one!
# 7ams
# ['A', 'B']
# Found one!
# 3pqy
# ['N', 'O']
# 4lcw
# ['G', 'H']
# Found one!
# 5c09
# ['I', 'J']
# 4mxq
# ['C', 'D']
# 6vtc
# ['A', 'B']
# 4prh
# ['D', 'E']
# Found one!
# 5jzi
# ['D', 'E']
# 6omg
# ['C', 'D']
# Found one!
# 1qrn
# ['D', 'E']
# 2p1y
# ['e', 'E']
# 3kxf
# ['D', 'E']
# 3pl6
# ['C', 'D']
# 2p1y
# ['c', 'A']
# 2bnq
# ['D', 'E']
# 4pjh
# ['E', 'F']
# 5c0a
# ['D', 'E']
# 3kxf
# ['G', 'H']
# Found one!
# 6p64
# ['I', 'J']
# 4ndm
# ['A', 'B']
# 4z7u
# ['E', 'F']
# 5wkf
# ['D', 'E']
# 6bnl
# ['C', 'D']
# Found one!
# 3e3q
# ['M', 'N']
# 5yxu
# ['F', 'G']
# 2nx5
# ['T', 'U']
# 1g6r
# ['A', 'B']
# 7llj
# ['A']
# 2po6
# ['G', 'H']
# 4zak
# ['C', 'D']
# 8gvb
# ['A', 'B']
# 6v80
# ['C', 'D']
# 6fum
# ['A', 'B']
# Found one!
# 5d7i
# ['E', 'F']
# 5d2l
# ['E', 'F']
# 7rm4
# ['T', 'S']
# 2p1y
# ['a', 'C']
# 6fur
# ['A', 'B']
# Found one!
# 6wl4
# ['I']
# 6bnl
# ['G', 'H']
# Found one!
# 7fjf
# ['m', 'n']
# 5wlg
# ['I', 'J']
# Found one!
# 2aq1
# ['G']
# 5nmg
# ['D', 'E']
# 2apt
# ['B']
# 6fun
# ['A', 'B']
# Found one!
# 5iw1
# ['E', 'F']
# 4may
# ['C', 'D']
# 3quz
# ['C', 'D']
# Found one!
# 4nqc
# ['G', 'H']
# Found one!
# 7byd
# ['I', 'J']
# 7lli
# ['E']
# 5hho
# ['D', 'E']
# Found one!
# 1qse
# ['D', 'E']
# 3c6l
# ['E', 'F']
# 5d5m
# ['G', 'H']
# 5hyj
# ['I', 'J']
# 4mnh
# ['A', 'B']
# 7lli
# ['L']
# 3sjv
# ['D', 'E']
# 5xov
# ['I', 'J']
# 3owe
# ['O']
# 2ypl
# ['D', 'E']
# 3rgv
# ['A', 'B']
# 1h5b
# ['C']
# Found one!
# 3c5z
# ['E', 'F']
# 5w1v
# ['D', 'E']
# 2cde
# ['C', 'D']
# 5nmd
# ['A', 'B']
# Found one!
# 4gkz
# ['A', 'B']
# Found one!
# 6cwb
# ['C', 'D']
# 1ac6
# ['B']
# 1g6r
# ['C', 'D']
# 3mbe
# ['G', 'H']
# 4pjd
# ['G', 'H']
# 5m01
# ['G', 'H']
# Found one!
# 6puf
# ['D', 'E']
# Found one!
# 7l15
# ['B']
# 4wnq
# ['C', 'D']
# Found one!
# 6mra
# ['A', 'B']
# Found one!
# 5swz
# ['N', 'O']
# Found one!
# 3c6l
# ['A', 'B']
# 8gvi
# ['A', 'B']
# 7n5c
# ['D', 'E']
# Found one!
# 7rm4
# ['O', 'N']
# 3q5y
# ['D']
# Found one!
# 3vxt
# ['A', 'B']
# 4ozg
# ['G', 'H']
# 3pqy
# ['I', 'J']
# 4ozh
# ['G', 'H']
# 2e7l
# ['B', 'C']
# 1hxm
# ['B', 'A']
# 2ol3
# ['A', 'B']
# 6fr3
# ['A', 'B']
# Found one!
# 6bj8
# ['D', 'H']
# Found one!
# 1l0y
# ['A']
# 7qpj
# ['A', 'B']
# Found one!
# 3vxm
# ['D', 'E']
# 6pvd
# ['G', 'H']
# Found one!
# 3vxq
# ['D', 'E']
# 4x6c
# ['E', 'F']
# 3owe
# ['C']
# 7byd
# ['D', 'E']
# 6c09
# ['C', 'D']
# Found one!
# 5u1r
# ['B', 'G']
# Found one!
# 6eqa
# ['D', 'E']
# 2aq1
# ['C']
# 2cde
# ['A', 'B']
# 6miy
# ['G', 'H']
# 5nmd
# ['C', 'D']
# Found one!
# 6dfx
# ['G', 'H']
# 6dfq
# ['G', 'H']
# Found one!
# 4apq
# ['C', 'D']
# 3utp
# ['D', 'E']
# 2ial
# ['C', 'D']
# 4y19
# ['D', 'E']
# Found one!
# 4nqd
# ['D', 'E']
# Found one!
# 6xqp
# ['E', 'F']
# Found one!
# 3c5z
# ['A', 'B']
# 4p5t
# ['E', 'F']
# 6bj3
# ['D', 'H']
# Found one!
# 7k0z
# ['B']
# 3qjh
# ['A', 'B']
# 1qsf
# ['D', 'E']
# 4mji
# ['D', 'E']
# 6mj6
# ['C', 'D']
# Found one!
# 1oga
# ['D', 'E']
# 5u16
# ['E', 'F']
# Found one!
# 2gj6
# ['D', 'E']
# 6cx5
# ['C', 'D']
# 4pjg
# ['E', 'F']
# Found one!
# 5e6i
# ['F', 'L']
# 3qdg
# ['D', 'E']
# 6vma
# ['D', 'E']
# 6mno
# ['A', 'B']
# 5d7k
# ['D', 'E']
# Found one!
# 3skn
# ['A', 'B']
# 7na5
# ['D', 'E']
# Found one!
# 5c07
# ['I', 'J']
# Found one!
# 5d7j
# ['A', 'B']
# Found one!
# 3o6f
# ['C', 'D']
# 5u72
# ['D', 'E']
# 6wl2
# ['F']
# 4pri
# ['D', 'E']
# Found one!
# 1hxm
# ['D', 'C']
# 7dzm
# ['E', 'D']
# 3r8b
# ['J']
# 3t0e
# ['C', 'D']
# 5m02
# ['G', 'H']
# Found one!
# 4pji
# ['G', 'H']
# Found one!
# 3axl
# ['A', 'B']
# 5d2l
# ['O', 'P']
# 2ckb
# ['C', 'D']
# 3tfk
# ['C', 'D']
# 3sjv
# ['I', 'J']
# 5ksb
# ['G', 'H']
# 3are
# ['C', 'D']
# Found one!
# 3axl
# ['G', 'H']
# 3mfg
# ['B']
# Found one!
# 8d5p
# ['A', 'B']
# 4qok
# ['D', 'E']
# 6wl2
# ['I']
# 2uwe
# ['E', 'F']
# Found one!
# 4l4v
# ['G', 'H']
# Found one!
# 3r8b
# ['D']
# 5c08
# ['D', 'E']
# 3hg1
# ['D', 'E']
# 3tf7
# ['i', 'I']
# 2eyt
# ['A', 'B']
# 5jhd
# ['D', 'E']
# 3e3q
# ['d', 'e']
# 3tn0
# ['C', 'D']
# 4mnq
# ['D', 'E']
# 6py2
# ['D', 'E']
# 4gg8
# ['A', 'B']
# 7dzn
# ['E', 'D']
# 7llj
# ['L']
# 3vwk
# ['C', 'D']
# Found one!
# 6rpb
# ['I', 'J']
# 6mnn
# ['A', 'B']
# 3byt
# ['G']
# 6at6
# ['A', 'B']
# Found one!
# 3sdx
# ['E', 'F']
# 7su9
# ['D', 'E']
# 7n1e
# ['D', 'E']
# 4ei6
# ['A', 'B']
# Found one!
# 4g8f
# ['A', 'B']
# Found one!
# 5u1r
# ['D', 'E']
# 7fje
# ['m', 'n']
# 4l9l
# ['A', 'B']
# 3qeq
# ['D', 'E']
# 5c0a
# ['I', 'J']
# 2cdg
# ['A', 'B']
# 4grl
# ['C', 'D']
# 3mff
# ['A', 'B']
# 3of6
# ['B']
# 6cuh
# ['A', 'B']
# Found one!
# 4e42
# ['A', 'B']
# 5tje
# ['G', 'H']
# 6cxa
# ['C', 'D']
# 3e3q
# ['V', 'W']
# 4wwk
# ['A', 'B']
# 3skn
# ['E', 'F']
# 5w1w
# ['D', 'E']
# 6pul
# ['D', 'E']
# Found one!
# 2vlj
# ['D', 'E']
# 5vcj
# ['C', 'D']
# 5xot
# ['D', 'E']
# 6cqn
# ['D', 'E']
# Found one!
# 3vxr
# ['D', 'E']
# 2wbj
# ['C', 'D']
# 5wki
# ['D', 'E']
# 5ks9
# ['E', 'F']
# 3skn
# ['C', 'D']
# Found one!
# 4eup
# ['G', 'H']
# 1tvd
# ['A']
# Found one!
# 7nmg
# ['D', 'E']
# Found one!
# 3d3v
# ['D', 'E']
# 6frb
# ['A', 'B']
# Found one!
# 6fur
# ['C', 'D']
# Found one!
# 5isz
# ['D', 'E']
# Found one!
# 6u3n
# ['D', 'E']
# 1bwm
# ['a', 'A']
# 6w9u
# ['D', 'E']
# Found one!
# 2vlr
# ['I', 'J']
# 2f54
# ['K', 'L']
# 6rsy
# ['D', 'E']
# Found one!
# 4mvb
# ['C', 'D']
# 1mi5
# ['D', 'E']
# 1sbb
# ['C']
# 4en3
# ['A', 'B']
# 1zgl
# ['U', 'V']
# 6cwe
# ['C', 'D']
# Found one!
# 3vxq
# ['A', 'B']
# 5swz
# ['I', 'J']
# 1h5b
# ['B']
# Found one!
# 3vxs
# ['D', 'E']
# 5w1w
# ['S', 'T']
# 2po6
# ['C', 'D']
# 8gvg
# ['A', 'B']
# 4qrr
# ['D', 'E']
# 2vlk
# ['D', 'E']
# 3sjv
# ['S', 'T']
# 6cx9
# ['C', 'D']
# 4pj7
# ['E', 'F']
# 4mng
# ['e', 'E']
# 4l4t
# ['G', 'H']
# Found one!
# 6eh4
# ['D', 'E']
# Found one!
# 6vm7
# ['D', 'E']
# 3tpu
# ['G', 'H']
# 5d7l
# ['D', 'E']
# 1d9k
# ['E', 'F']
# 3uts
# ['I', 'J']
# 6cqq
# ['D', 'E']
# Found one!
# 3owe
# ['G']
# 4l4v
# ['D', 'E']
# Found one!
# 2aq3
# ['E']
# 5hhm
# ['I', 'J']
# Found one!
# 1h5b
# ['D']
# Found one!
# 6mji
# ['C', 'D']
# Found one!
# 3sjv
# ['N', 'O']
# 3e3q
# ['R', 'S']
# 4n0c
# ['G', 'H']
# 5c0b
# ['I', 'J']
# 7pb2
# ['D', 'E']
# 6xng
# ['C', 'D']
# 4e41
# ['I', 'J']
# 3q5y
# ['B']
# 5til
# ['K', 'L']
# 4qrp
# ['J', 'I']
# 6rpa
# ['D', 'E']
# 6xqp
# ['G', 'H']
# Found one!
# 2e7l
# ['A', 'D']
# 7n5p
# ['D', 'E']
# Found one!
# 3to4
# ['C', 'D']
# 4pjc
# ['G', 'H']
# 3o6f
# ['G', 'H']
# 1jck
# ['C']
# 7n1f
# ['D', 'E']
# 5c0c
# ['D', 'E']
# 5ksb
# ['E', 'F']
# 7sg1
# ['D', 'E']
# 6d78
# ['D', 'E']
# 6uz1
# ['D', 'E']
# 6vrm
# ['D', 'E']
# 3e3q
# ['D', 'E']
# 1zgl
# ['Q', 'R']
# 6pui
# ['D', 'E']
# Found one!
# 2bnu
# ['A', 'B']
# 4n5e
# ['C', 'D']
# 6pum
# ['D', 'E']
# Found one!
# 7jwi
# ['D', 'E']
# Found one!
# 5wjo
# ['A', 'B']
# Found one!
# 3of6
# ['C']
# 4p5t
# ['A', 'B']
# 4pjb
# ['E', 'F']
# 2ij0
# ['C']
# 4jrx
# ['D', 'E']
# Found one!
# 7nmf
# ['D', 'E']
# 3sdc
# ['C', 'D']
# 6dfv
# ['A', 'B']
# Found one!
# 6jxr
# ['m', 'n']
# 3qiw
# ['C', 'D']
# 6cqr
# ['I', 'J']
# Found one!
# 7z50
# ['H', 'E']
# 6cug
# ['D', 'E']
# 2aq1
# ['E']
# 6zkx
# ['D', 'E']
# Found one!
# 6fr6
# ['A', 'B']
# Found one!
# 3mc0
# ['C']
# 4ms8
# ['C', 'D']
# 4nqc
# ['D', 'E']
# Found one!
# 2ak4
# ['N', 'P']
# 5c09
# ['D', 'E']
# 2apv
# ['A']
# 3qjf
# ['C', 'D']
# 4jfh
# ['D', 'E']
# 5d2l
# ['I', 'J']
# 4onh
# ['A', 'B']
# 4p2q
# ['N', 'O']
# 7n1d
# ['A', 'B']
# 6pvc
# ['G', 'H']
# Found one!
# 3c60
# ['A', 'B']
# 5yxu
# ['A', 'B']
# 4z7v
# ['G', 'H']
# 6fra
# ['A', 'B']
# Found one!
# 2axj
# ['B']
# 4pj5
# ['D', 'E']
# Found one!
# 2nx5
# ['N', 'P']
# 6mnm
# ['A', 'B']
# 4l3e
# ['D', 'E']
# 3o4l
# ['D', 'E']
# Found one!
# 6mjq
# ['G', 'H']
# Found one!
# 1i9e
# ['A']
# 4y4f
# ['C', 'D']
# Found one!
# 6pug
# ['G', 'H']
# Found one!
# 2pyf
# ['A', 'B']
# Found one!
# 3sdd
# ['C', 'D']
# 3arf
# ['C', 'D']
# Found one!
# 6dfs
# ['A', 'B']
# 1ktk
# ['F']
# 7sg2
# ['I', 'J']
# 2xn9
# ['A', 'B']
# Found one!
# 3he7
# ['C', 'D']
# 6puc
# ['D', 'E']
# Found one!
# 4pjx
# ['G', 'H']
# 6dfw
# ['E', 'F']
# 4p23
# ['A', 'B']
# 5nme
# ['I', 'J']
# 1kgc
# ['D', 'E']
# 6bnk
# ['C', 'D']
# 5d2n
# ['D', 'E']
# 7n1c
# ['D', 'E']
# 3qeu
# ['A', 'B']
# Found one!
# 4nqe
# ['D', 'E']
# Found one!
# 4elk
# ['C', 'D']
# Found one!
# 2aq1
# ['A']
# 6vth
# ['A', 'B']
# 2jcc
# ['E', 'F']
# 6miy
# ['C', 'D']
# 5euo
# ['G', 'H']
# 6g9q
# ['G', 'H']
# 4pjh
# ['G', 'H']
# Found one!
# 5c0b
# ['D', 'E']
# 2wbj
# ['G', 'H']
# 6vmx
# ['I', 'J']
# 3utp
# ['K', 'L']
# 3tf7
# ['g', 'G']
# 1b88
# ['B']
# 6dkp
# ['D', 'E']
# 3quy
# ['C', 'D']
# Found one!
# 6puf
# ['G', 'H']
# Found one!
# 6d7g
# ['E', 'D']
# 3q5y
# ['C']
# Found one!
# 6l9l
# ['C', 'D']
# 6vm8
# ['D', 'E']
# 5nqk
# ['A', 'B']
# 2pye
# ['D', 'E']
# Found one!
# 6pud
# ['D', 'E']
# Found one!
# 3tzv
# ['G', 'H']
# 6eh6
# ['A', 'B']
# 2jcc
# ['L', 'M']
# 4p4k
# ['G', 'H']
# 4pje
# ['G', 'H']
# Found one!
# 6r2l
# ['D', 'E']
# Found one!
# 4x6b
# ['A', 'B']
# 2oi9
# ['B', 'C']
# 6fr4
# ['A', 'B']
# Found one!
# 4pja
# ['G', 'H']
# 4mnh
# ['C', 'D']
# 3kxf
# ['M', 'O']
# 3r8b
# ['H']
# 6xc9
# ['I', 'J']
# Found one!
# 5wlg
# ['D', 'E']
# Found one!
# 3qjh
# ['C', 'D']
# 3r8b
# ['P']
# 1ac6
# ['A']
# 6wl3
# ['C']
# 4c56
# ['A', 'B']
# 4pji
# ['E', 'F']
# 3arb
# ['C', 'D']
# Found one!
# 6wl4
# ['F']
# 4pja
# ['E', 'F']
# 3pqy
# ['D', 'E']
# 5d7j
# ['G', 'H']
# Found one!
# 6bga
# ['C', 'D']
# Found one!
# 1lp9
# ['E', 'F']
# 6mjj
# ['C', 'D']
# Found one!
# 3mff
# ['C', 'D']
# 5u6q
# ['B', 'G']
# 1hxm
# ['F', 'E']
# 4l4t
# ['D', 'E']
# Found one!
# 3skn
# ['G', 'H']
# 1nfd
# ['A', 'B']
# 3mv7
# ['D', 'E']
# Found one!
# 3e3q
# ['I', 'J']
# 3owe
# ['K']
# 4h1l
# ['G', 'H']
# 2axj
# ['A']
# 2icw
# ['I', 'J']
# Found one!
# 5wkh
# ['D', 'E']
# 7l1d
# ['D', 'E']
# 6rp9
# ['D', 'E']
# 5e9d
# ['I', 'J']
# 7n6e
# ['I', 'J']
# 2ak4
# ['T', 'U']
# 5nmg
# ['I', 'J']
# 5w1w
# ['N', 'O']
# 6uon
# ['G', 'H']
# 6puj
# ['D', 'E']
# Found one!
# 4pjx
# ['E', 'F']
# 4ei5
# ['G', 'H']
# Found one!
# 6dfv
# ['C', 'D']
# Found one!
# 5u6q
# ['D', 'E']
# Found one!
# 2q86
# ['A', 'B']
# 7f5k
# ['A', 'B']
# 3he6
# ['C', 'D']
# 6mss
# ['A', 'B']
# Found one!
# 4pjb
# ['G', 'H']
# 4e42
# ['C', 'D']
# 2apx
# ['A']
# 6amu
# ['D', 'E']
# 3of6
# ['A']
# 3tzv
# ['A', 'B']
# 6rsy
# ['I', 'J']
# 4y4h
# ['G', 'H']
# 5u2v
# ['E', 'F']
# 5brz
# ['D', 'E']
# 3o9w
# ['C', 'D']
# 3sda
# ['C', 'D']
# 5eu6
# ['D', 'E']
# Found one!
# 3tjh
# ['C', 'D']
# 4l8s
# ['A', 'B']
# 5u17
# ['D', 'E']
# Found one!
# 3h9s
# ['D', 'E']
# 2aq3
# ['C']
# 5e6i
# ['G', 'H']
# 3dx9
# ['A', 'B']
# Found one!
# 5e6i
# ['A', 'B']
# 3qjf
# ['A', 'B']
# 1mwa
# ['A', 'B']
# 4elm
# ['E', 'F']
# 7m72
# ['C', 'D']
# 7ryn
# ['C', 'D']
# 4prp
# ['D', 'E']
# 4lcc
# ['A', 'B']
# 3owe
# ['M']
# 2ial
# ['A', 'B']
# 1bec
# ['A']
# 2ian
# ['N', 'O']
# 1kj2
# ['A', 'B']
# 6cxe
# ['C', 'D']
# 4y1a
# ['D', 'E']
# 5nmf
# ['D', 'E']
# 6eh8
# ['A', 'B']
# Found one!
# 6xc9
# ['D', 'E']
# Found one!
# 2cde
# ['E', 'F']
# 3e3q
# ['C', 'F']
# 2iam
# ['C', 'D']
# 6u3o
# ['G', 'H']
# 3tvm
# ['G', 'H']
# 6v0y
# ['D', 'E']
# 3r8b
# ['B']
# 3utt
# ['I', 'J']
# 5w1v
# ['I', 'J']
# 3byt
# ['A']
# 8d5p
# ['C', 'D']
# 1mwa
# ['C', 'D']
# 7f5k
# ['C', 'D']
# 5fka
# ['A', 'B']
# 2vlr
# ['D', 'E']
# 6lir
# ['A', 'B']
# 6mwr
# ['C', 'D']
# 6w9v
# ['D', 'E']
# Found one!
# 4n0c
# ['C', 'D']
# 2p1y
# ['g', 'G']
# 2ian
# ['I', 'J']
# 1ypz
# ['H', 'G']
# 6u3o
# ['A', 'B']
# 2eyr
# ['A', 'B']
# 2xna
# ['A', 'B']
# Found one!
# 3owe
# ['A']
# 2pxy
# ['A', 'B']
# 3vxt
# ['C', 'D']
# 6xco
# ['D', 'E']
# 3kxf
# ['N', 'P']
# Found one!
# 5c08
# ['I', 'J']
# 6dfq
# ['C', 'D']
# Found one!
# 1ao7
# ['D', 'E']
# 5swz
# ['S', 'T']
# 4g9f
# ['D', 'E']
# Found one!
# 3qib
# ['C', 'D']
# 4ei6
# ['C', 'D']
# Found one!
# 3vwj
# ['C', 'D']
# 6pui
# ['B', 'G']
# Found one!
# 5tez
# ['I', 'J']
# 6xqq
# ['A', 'B']
# Found one!
# 5fk9
# ['A', 'B']
# 4qrp
# ['D', 'E']
# 4pje
# ['E', 'F']
# Found one!
# 6zkw
# ['D', 'E']
# 4ftv
# ['D', 'E']
# Found one!
# 6c68
# ['C', 'D']
# 6px6
# ['D', 'E']
# 6v1a
# ['D', 'E']
# Found one!
# 7pb2
# ['I', 'J']
# 2nx5
# ['D', 'E']
# 4ozi
# ['E', 'F']
# 6puk
# ['D', 'E']
# Found one!
# 7z50
# ['G', 'F']
# 1u3h
# ['E', 'F']
# 6dfq
# ['E', 'F']
# 4p2q
# ['D', 'E']
# 7ea6
# ['A', 'B']
# 4ozh
# ['E', 'F']
# 6mjq
# ['C', 'D']
# Found one!
# 3rug
# ['G', 'H']
# 2ckb
# ['A', 'B']
# 1ypz
# ['F', 'E']
# 6vrn
# ['D', 'E']
# 6mkr
# ['A', 'B']
# 2esv
# ['D', 'E']
# 3dxa
# ['I', 'J']
# 6fr8
# ['A', 'B']
# Found one!
# 5u2v
# ['G', 'H']
# 3byt
# ['C']
# 4grm
# ['C', 'D']
# 1l0y
# ['C']
# 2ij0
# ['E']
# 5hhm
# ['D', 'E']
# Found one!
# 4pjc
# ['E', 'F']
# 4pjd
# ['E', 'F']
# 3sdx
# ['G', 'H']
# 4jfd
# ['D', 'E']
# 4pj5
# ['G', 'H']
# Found one!
# 2apt
# ['A']
# 6zky
# ['D', 'E']
# 5jhd
# ['I', 'J']
# 6uln
# ['D', 'E']
# 4p2q
# ['S', 'T']
# 6v80
# ['H', 'I']
# 5nmf
# ['I', 'J']
# 3mbe
# ['C', 'D']
# 7amq
# ['A', 'B']
# 6tro
# ['D', 'E']
# 3scm
# ['C', 'D']
# 6vqo
# ['H', 'J']
# 3q5t
# ['A']
# 1b88
# ['A']
# 7r80
# ['A', 'B']
# 1h5b
# ['A']
# Found one!
# 4y4f
# ['G', 'H']
# 6rpb
# ['N', 'O']
# 1bd2
# ['D', 'E']
# 6fuq
# ['A', 'B']
# Found one!
# 4z7w
# ['G', 'H']
# 7phr
# ['A', 'B']
# 3c60
# ['E', 'F']
# 4y4h
# ['C', 'D']
# 6pue
# ['G', 'H']
# Found one!
# 4udt
# ['A', 'B']
# Found one!
# 6xqq
# ['C', 'D']
# Found one!
# 6eh7
# ['A', 'B']
# 3ffc
# ['I', 'J']
# Found one!
# 1u3h
# ['A', 'B']
# 4pjf
# ['E', 'F']
# 4jry
# ['D', 'E']
# 2eyt
# ['C', 'D']
# 4zdh
# ['A', 'B']
# 4iiq
# ['A', 'B']
# 5u72
# ['B', 'G']
# 1tcr
# ['A', 'B']
# 4p46
# ['A', 'B']
# 5sws
# ['D', 'E']
# Found one!
# 7k0x
# ['B']
# 3ffc
# ['D', 'E']
# 1jck
# ['A']
# 5yxn
# ['A', 'B']
# 6dfw
# ['G', 'H']
# Found one!
# 1fo0
# ['A', 'B']
# 7ryl
# ['C', 'D']
# Found one!
# 4c56
# ['G', 'H']
# 2apw
# ['A']
# 5d2l
# ['K', 'L']
# 6eh5
# ['A', 'B']
# Found one!
# 6bnk
# ['G', 'H']
# 6cw6
# ['C', 'D']
# 4p2r
# ['I', 'J']
# 3qh3
# ['A', 'B']
# Found one!
# 2axh
# ['B']
# 6pud
# ['G', 'H']
# Found one!
# 3tyf
# ['C', 'D']
# 1fyt
# ['D', 'E']
# 3qfj
# ['D', 'E']
# 2j8u
# ['E', 'F']
# 4x6b
# ['C', 'D']
# 4y2d
# ['C', 'D']
# 2nts
# ['P']
# 3r8b
# ['N']
# 6lir
# ['C', 'D']
# 2eys
# ['A', 'B']
# 4irj
# ['C', 'D']
# 3huj
# ['E', 'F']
# Found one!
# 3gsn
# ['A', 'B']
# 3rzc
# ['C', 'D']
# 6ovo
# ['A', 'B']
# 2ian
# ['D', 'E']
# 5c0c
# ['I', 'J']
# 2uwe
# ['L', 'M']
# 2ian
# ['S', 'T']
# 5w1w
# ['I', 'J']
# 6dfx
# ['I', 'J']
# 3r8b
# ['F']
# 5e9d
# ['D', 'E']
# 4lcw
# ['D', 'E']
# Found one!
# 6v13
# ['D', 'E']
# 6uz1
# ['I', 'J']
# 6w9v
# ['G', 'H']
# Found one!
# 1tvd
# ['B']
# Found one!
# 7ow6
# ['D', 'E']
# 6cqq
# ['I', 'J']
# Found one!
# 5euo
# ['E', 'F']
# 2aq2
# ['A']
# 4g8g
# ['D', 'E']
# Found one!
# 4ozf
# ['G', 'H']
# 4p2r
# ['S', 'T']
# 4y2d
# ['G', 'H']
# 5nme
# ['D', 'E']
# 4p2r
# ['D', 'E']
# 4jfe
# ['D', 'E']
# Found one!
# 6pue
# ['D', 'E']
# Found one!
# 2apb
# ['A']
# 4ww1
# ['A', 'B']
# Found one!
# 3mv9
# ['D', 'E']
# Found one!
# 6cph
# ['D', 'E']
# Found one!
# 6frc
# ['A', 'B']
# Found one!
# 6q3s
# ['D', 'E']
# 6puk
# ['B', 'G']
# Found one!
# 5d5m
# ['E', 'F']
# Found one!
# 6fr5
# ['A', 'B']
# Found one!
# 5men
# ['D', 'E']
# 3vxu
# ['I', 'J']
# 6fup
# ['A', 'B']
# Found one!
# 4jff
# ['D', 'E']
# Found one!
# 6pul
# ['B', 'G']
# Found one!
# 4ozg
# ['E', 'F']
# 7sg2
# ['D', 'E']
# 6miv
# ['C', 'D']
# 3rtq
# ['C', 'D']
# 3dxa
# ['N', 'O']
# 1d9k
# ['A', 'B']
# 4gg6
# ['G', 'H']
# 2apf
# ['A']
# 234 out of 895 have alternate residue conformations.
