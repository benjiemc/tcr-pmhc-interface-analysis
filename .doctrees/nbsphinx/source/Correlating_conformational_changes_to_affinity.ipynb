# %% [markdown]
# # Correlating conformational changes to affinity

# %% [markdown]
# ## Introduction
#
# The following notebook aims to correlate the changes observed between *apo* and *holo* conformations with the affinity of the interactions. The ATLAS dataset is be used to collect affinities on the interactions.

# %%
import re

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import scipy
import seaborn as sns

# %% [markdown]
# ## Loading and cleaning the ATLAS dataset

# %%
atlas = pd.read_excel('../data/external/ATLAS.xlsx', sheet_name='Mutants_052016', index_col='Index')
atlas
# Out:
#       TCRname      MHCname  MHCname_PDB MHC_mut MHC_mut_chain TCR_mut  \
# Index
# 1        LC13  HLA-B*08:01  HLA-B*08:01      WT           NaN      WT
# 2        LC13  HLA-B*08:01  HLA-B*08:01      WT           NaN    S25A
# 3        LC13  HLA-B*08:01  HLA-B*08:01      WT           NaN    T26A
# 4        LC13  HLA-B*08:01  HLA-B*08:01      WT           NaN    S28A
# 5        LC13  HLA-B*08:01  HLA-B*08:01      WT           NaN    T30A
# ...       ...          ...          ...     ...           ...     ...
# 690       2B4         I-Ek         I-Ek      WT           NaN      WT
# 691       2B4         I-Ek         I-Ek      WT           NaN      WT
# 692       2B4         I-Ek         I-Ek      WT           NaN      WT
# 693       2B4         I-Ek         I-Ek      WT           NaN      WT
# 694        2C        H-2Ld        H-2Ld      WT           NaN      WT
#
#            Kd_microM Kon_per_M_per_s Koff_per_s Kd_wt/Kd_mut  ...  \
# Index                                                         ...
# 1       12.5 +/- 2.1              \N         \N            1  ...
# 2      14.8 +/- 0.55              \N         \N         0.84  ...
# 3      19.4 +/- 0.55              \N         \N         0.64  ...
# 4      11.7 +/- 0.85              \N         \N         1.07  ...
# 5       33.7 +/- 1.2              \N         \N         0.37  ...
# ...              ...             ...        ...          ...  ...
# 690             n.d.            n.d.       n.d.          NaN  ...
# 691             33.8            3950      0.134         0.16  ...
# 692             43.4            4030        680         0.13  ...
# 693             42.9            4200       0.18         0.13  ...
# 694              1.2             NaN        NaN          NaN  ...
#
#       TCR_mut_chain   CDR  wtCDRseq TCR_PDB_chain      PMID     Exp. Method  \
# Index
# 1               NaN    \N        \N            \N  15640805    Biacore 3000
# 2                 A  CDR1   TISGTDY             D  15640805    Biacore 3000
# 3                 A  CDR1   TISGTDY             D  15640805    Biacore 3000
# 4                 A  CDR1   TISGTDY             D  15640805    Biacore 3000
# 5                 A  CDR1   TISGTDY             D  15640805    Biacore 3000
# ...             ...   ...       ...           ...       ...             ...
# 690             NaN   NaN       NaN           NaN  12152083         Biacore
# 691             NaN   NaN       NaN           NaN  12152083         Biacore
# 692             NaN   NaN       NaN           NaN  12152083         Biacore
# 693             NaN   NaN       NaN           NaN  12152083         Biacore
# 694             NaN   NaN       NaN           NaN  19755422  flow cytometry
#
#       SPR SensorChip     Immobilized Ligand Coupling Method    Analyte
# Index
# 1                CM5  FLRGRAYGL-HLA-B*08:01          direct    LC13 WT
# 2                CM5  FLRGRAYGL-HLA-B*08:01          direct  LC13 S25A
# 3                CM5  FLRGRAYGL-HLA-B*08:01          direct  LC13 T26A
# 4                CM5  FLRGRAYGL-HLA-B*08:01          direct  LC13 S28A
# 5                CM5  FLRGRAYGL-HLA-B*08:01          direct  LC13 T30A
# ...              ...                    ...             ...        ...
# 690              NaN   ANERADLIAYLKQAAK-IEk        indirect     2B4 WT
# 691              NaN   ANERADLIAYLKQASK-IEk        indirect     2B4 WT
# 692              NaN   ANERADLIAYLKQANK-IEk        indirect     2B4 WT
# 693              NaN   ANERADLIAFLKQASK-IEk        indirect     2B4 WT
# 694              NaN                    NaN             NaN        NaN
#
# [694 rows x 32 columns]

# %%
atlas_with_pdb = atlas.query('true_PDB.notna()').copy()

# %%
atlas_with_pdb_wt = atlas_with_pdb.query("MHC_mut == TCR_mut == 'WT'").copy()

# %%
pattern = re.compile(r'\s*\+/\-\s*')

kds = atlas_with_pdb_wt['Kd_microM'].apply(str).map(pattern.split).apply(pd.Series)
kds.columns = ['kd', 'error']
kds = kds.replace('n.d.', np.nan)
kds.loc[kds['kd'].fillna('').str.startswith('>'), 'kd'] = np.nan

kds['kd'] = kds['kd'].apply(float)
kds['error'] = kds['error'].apply(float)

atlas_with_pdb_wt[['kd', 'kd_error']] = kds

atlas_with_pdb_wt = atlas_with_pdb_wt[atlas_with_pdb_wt['kd'].notnull()].copy()

atlas_with_pdb_wt
# Out:
#        TCRname      MHCname  MHCname_PDB MHC_mut MHC_mut_chain TCR_mut  \
# Index
# 1         LC13  HLA-B*08:01  HLA-B*08:01      WT           NaN      WT
# 40        JM22  HLA-A*02:01  HLA-A*02:01      WT           NaN      WT
# 63          A6  HLA-A*02:01  HLA-A*02:01      WT           NaN      WT
# 90        RA14  HLA-A*02:01  HLA-A*02:01      WT           NaN      WT
# 100       MEL5  HLA-A*02:01  HLA-A*02:01      WT           NaN      WT
# ...        ...          ...          ...     ...           ...     ...
# 665       42F3        H-2Ld        H-2Ld      WT           NaN      WT
# 666    J809.B5         I-Ab         I-Ab      WT           NaN      WT
# 668      14.C6         I-Ab         I-Ab      WT           NaN      WT
# 669        2B4         I-Ek         I-Ek      WT           NaN      WT
# 694         2C        H-2Ld        H-2Ld      WT           NaN      WT
#
#           Kd_microM Kon_per_M_per_s Koff_per_s Kd_wt/Kd_mut  ... wtCDRseq  \
# Index                                                        ...
# 1      12.5 +/- 2.1              \N         \N            1  ...       \N
# 40              5.2           31000       0.16            1  ...       \N
# 63         2.113503           51100      0.108            1  ...       \N
# 90     27.7 +/- 2.3              \N         \N            1  ...       \N
# 100              18              \N         \N         0.36  ...       \N
# ...             ...             ...        ...          ...  ...      ...
# 665              48             NaN        NaN          NaN  ...      NaN
# 666              32             NaN        NaN          NaN  ...      NaN
# 668               5             NaN        NaN          NaN  ...      NaN
# 669             5.5            4000      0.022          NaN  ...      NaN
# 694             1.2             NaN        NaN          NaN  ...      NaN
#
#       TCR_PDB_chain      PMID     Exp. Method SPR SensorChip  \
# Index
# 1                \N  15640805    Biacore 3000            CM5
# 40               \N  18275829    Biacore 2000            CM5
# 63               \N  18767161    Biacore 3000            CM5
# 90               \N  19542454    Biacore 3000            CM5
# 100              \N  19605354    Biacore T100            CM5
# ...             ...       ...             ...            ...
# 665             NaN  22301545             NaN            NaN
# 666             NaN  24813203    Biacore 3000            NaN
# 668             NaN  24813203    Biacore 3000            NaN
# 669             NaN  12152083         Biacore            NaN
# 694             NaN  19755422  flow cytometry            NaN
#
#            Immobilized Ligand Coupling Method                Analyte  \
# Index
# 1       FLRGRAYGL-HLA-B*08:01          direct                LC13 WT
# 40      GILGFVFTL-HLA-A*02:01        indirect                JM22 WT
# 63                      A6 WT          direct  LLFGYPVYV-HLA-A*02:01
# 90                    RA14 WT          direct  NLVPMVATV-HLA-A*02:01
# 100    ELAGIGILTV-HLA-A*02:01        indirect                MEL5 WT
# ...                       ...             ...                    ...
# 665                       NaN             NaN                    NaN
# 666         FEAQKAKANKAVD-IAb        indirect             J809.B5 WT
# 668         FEAQKAKANKAVD-IAb        indirect               14.C6 WT
# 669      ANERADLIAYLKQATK-IEk        indirect                 2B4 WT
# 694                       NaN             NaN                    NaN
#
#               kd kd_error
# Index
# 1      12.500000      2.1
# 40      5.200000      NaN
# 63      2.113503      NaN
# 90     27.700000      2.3
# 100    18.000000      NaN
# ...          ...      ...
# 665    48.000000      NaN
# 666    32.000000      NaN
# 668     5.000000      NaN
# 669     5.500000      NaN
# 694     1.200000      NaN
#
# [100 rows x 34 columns]

# %%
atlas_with_pdb_wt['pdb_id'] = atlas_with_pdb['true_PDB'].str.lower()

# %%
num_structures_in_atlas = len(atlas_with_pdb_wt['pdb_id'].unique())

print('There are', num_structures_in_atlas, 'structures in the ATLAS dataset with affinity data for the wild type structures')
# Out:
# There are 73 structures in the ATLAS dataset with affinity data for the wild type structures

# %% [markdown]
# ## Loading apo-holo dataset

# %%
summary_df = pd.read_csv('../data/processed/apo-holo-tcr-pmhc-class-I/apo_holo_summary.csv')
summary_df
# Out:
#                        file_name pdb_id structure_type state alpha_chain  \
# 0    1ao7_D-E-C-A-B_tcr_pmhc.pdb   1ao7       tcr_pmhc  holo           D
# 1            1b0g_C-A-B_pmhc.pdb   1b0g           pmhc   apo         NaN
# 2            1b0g_F-D-E_pmhc.pdb   1b0g           pmhc   apo         NaN
# 3    1bd2_D-E-C-A-B_tcr_pmhc.pdb   1bd2       tcr_pmhc  holo           D
# 4            1bii_P-A-B_pmhc.pdb   1bii           pmhc   apo         NaN
# ..                           ...    ...            ...   ...         ...
# 386          7rtd_C-A-B_pmhc.pdb   7rtd           pmhc   apo         NaN
# 387  7rtr_D-E-C-A-B_tcr_pmhc.pdb   7rtr       tcr_pmhc  holo           D
# 388  8gvb_A-B-P-H-L_tcr_pmhc.pdb   8gvb       tcr_pmhc  holo           A
# 389  8gvg_A-B-P-H-L_tcr_pmhc.pdb   8gvg       tcr_pmhc  holo           A
# 390  8gvi_A-B-P-H-L_tcr_pmhc.pdb   8gvi       tcr_pmhc  holo           A
#
#     beta_chain antigen_chain mhc_chain1 mhc_chain2  \
# 0            E             C          A          B
# 1          NaN             C          A          B
# 2          NaN             F          D          E
# 3            E             C          A          B
# 4          NaN             P          A          B
# ..         ...           ...        ...        ...
# 386        NaN             C          A          B
# 387          E             C          A          B
# 388          B             P          H          L
# 389          B             P          H          L
# 390          B             P          H          L
#
#                                 cdr_sequences_collated peptide_sequence  \
# 0    DRGSQS-IYSNGD-AVTTDSWGKLQ-MNHEY-SVGAGI-ASRPGLA...        LLFGYPVYV
# 1                                                  NaN        ALWGFFPVL
# 2                                                  NaN        ALWGFFPVL
# 3    NSMFDY-ISSIKDK-AAMEGAQKLV-MNHEY-SVGAGI-ASSYPGG...        LLFGYPVYV
# 4                                                  NaN       RGPGRAFVTI
# ..                                                 ...              ...
# 386                                                NaN        YLQPRTFLL
# 387     DRGSQS-IYSNGD-AVNRDDKII-SEHNR-FQNEAQ-ASSPDIEQY        YLQPRTFLL
# 388  YGATPY-YFSGDTLV-AVGFTGGGNKLT-SEHNR-FQNEAQ-ASSD...         RYPLTFGW
# 389  YGATPY-YFSGDTLV-AVGFTGGGNKLT-SEHNR-FQNEAQ-ASSD...         RFPLTFGW
# 390  YGATPY-YFSGDTLV-AVVFTGGGNKLT-SEHNR-FQNEAQ-ASSL...         RYPLTFGW
#
#         mhc_slug
# 0    hla_a_02_01
# 1    hla_a_02_01
# 2    hla_a_02_01
# 3    hla_a_02_01
# 4          h2_dd
# ..           ...
# 386  hla_a_02_01
# 387  hla_a_02_01
# 388  hla_a_24_02
# 389  hla_a_24_02
# 390  hla_a_24_02
#
# [391 rows x 12 columns]

# %%
summary_df['id'] = summary_df['file_name'].str.replace(r'.pdb$', '', regex=True)
summary_df = summary_df.set_index('id')

# %% [markdown]
# ## Loading TCR data

# %%
conformational_change_tcr = pd.read_csv('../data/processed/apo-holo-tcr-pmhc-class-I-comparisons/rmsd_cdr_fw_align_results.csv')
conformational_change_tcr
# Out:
#                   complex_id             structure_x_name  \
# 0    3qdg_D-E-C-A-B_tcr_pmhc  3qdg_D-E-C-A-B_tcr_pmhc.pdb
# 1    3qdg_D-E-C-A-B_tcr_pmhc  3qdg_D-E-C-A-B_tcr_pmhc.pdb
# 2    3qdg_D-E-C-A-B_tcr_pmhc  3qdg_D-E-C-A-B_tcr_pmhc.pdb
# 3    3qdg_D-E-C-A-B_tcr_pmhc  3qdg_D-E-C-A-B_tcr_pmhc.pdb
# 4    3qdg_D-E-C-A-B_tcr_pmhc  3qdg_D-E-C-A-B_tcr_pmhc.pdb
# ..                       ...                          ...
# 809  7rtr_D-E-C-A-B_tcr_pmhc             7n1d_A-B_tcr.pdb
# 810  7rtr_D-E-C-A-B_tcr_pmhc             7n1d_A-B_tcr.pdb
# 811  7rtr_D-E-C-A-B_tcr_pmhc             7n1d_A-B_tcr.pdb
# 812  7rtr_D-E-C-A-B_tcr_pmhc             7n1d_A-B_tcr.pdb
# 813  7rtr_D-E-C-A-B_tcr_pmhc             7n1d_A-B_tcr.pdb
#
#                 structure_y_name   chain_type  cdr      rmsd
# 0               3qeu_A-B_tcr.pdb  alpha_chain    1  1.932806
# 1               3qeu_A-B_tcr.pdb  alpha_chain    2  1.308598
# 2               3qeu_A-B_tcr.pdb  alpha_chain    3  1.244062
# 3               3qeu_A-B_tcr.pdb   beta_chain    1  0.809066
# 4               3qeu_A-B_tcr.pdb   beta_chain    2  0.688597
# ..                           ...          ...  ...       ...
# 809  7rtr_D-E-C-A-B_tcr_pmhc.pdb  alpha_chain    2  0.810170
# 810  7rtr_D-E-C-A-B_tcr_pmhc.pdb  alpha_chain    3  0.563263
# 811  7rtr_D-E-C-A-B_tcr_pmhc.pdb   beta_chain    1  0.399182
# 812  7rtr_D-E-C-A-B_tcr_pmhc.pdb   beta_chain    2  0.284455
# 813  7rtr_D-E-C-A-B_tcr_pmhc.pdb   beta_chain    3  0.432453
#
# [814 rows x 6 columns]

# %%
conformational_change_tcr = conformational_change_tcr.merge(
    summary_df[['file_name', 'pdb_id', 'structure_type', 'state']],
    how='left',
    left_on='structure_x_name',
    right_on='file_name',
).merge(
    summary_df[['file_name', 'pdb_id', 'structure_type', 'state']],
    how='left',
    left_on='structure_y_name',
    right_on='file_name',
    suffixes=('_x', '_y')
).merge(
    summary_df[['cdr_sequences_collated', 'peptide_sequence', 'mhc_slug']],
    how='left',
    left_on='complex_id',
    right_index=True,
)

conformational_change_tcr
# Out:
#                   complex_id             structure_x_name  \
# 0    3qdg_D-E-C-A-B_tcr_pmhc  3qdg_D-E-C-A-B_tcr_pmhc.pdb
# 1    3qdg_D-E-C-A-B_tcr_pmhc  3qdg_D-E-C-A-B_tcr_pmhc.pdb
# 2    3qdg_D-E-C-A-B_tcr_pmhc  3qdg_D-E-C-A-B_tcr_pmhc.pdb
# 3    3qdg_D-E-C-A-B_tcr_pmhc  3qdg_D-E-C-A-B_tcr_pmhc.pdb
# 4    3qdg_D-E-C-A-B_tcr_pmhc  3qdg_D-E-C-A-B_tcr_pmhc.pdb
# ..                       ...                          ...
# 809  7rtr_D-E-C-A-B_tcr_pmhc             7n1d_A-B_tcr.pdb
# 810  7rtr_D-E-C-A-B_tcr_pmhc             7n1d_A-B_tcr.pdb
# 811  7rtr_D-E-C-A-B_tcr_pmhc             7n1d_A-B_tcr.pdb
# 812  7rtr_D-E-C-A-B_tcr_pmhc             7n1d_A-B_tcr.pdb
# 813  7rtr_D-E-C-A-B_tcr_pmhc             7n1d_A-B_tcr.pdb
#
#                 structure_y_name   chain_type  cdr      rmsd  \
# 0               3qeu_A-B_tcr.pdb  alpha_chain    1  1.932806
# 1               3qeu_A-B_tcr.pdb  alpha_chain    2  1.308598
# 2               3qeu_A-B_tcr.pdb  alpha_chain    3  1.244062
# 3               3qeu_A-B_tcr.pdb   beta_chain    1  0.809066
# 4               3qeu_A-B_tcr.pdb   beta_chain    2  0.688597
# ..                           ...          ...  ...       ...
# 809  7rtr_D-E-C-A-B_tcr_pmhc.pdb  alpha_chain    2  0.810170
# 810  7rtr_D-E-C-A-B_tcr_pmhc.pdb  alpha_chain    3  0.563263
# 811  7rtr_D-E-C-A-B_tcr_pmhc.pdb   beta_chain    1  0.399182
# 812  7rtr_D-E-C-A-B_tcr_pmhc.pdb   beta_chain    2  0.284455
# 813  7rtr_D-E-C-A-B_tcr_pmhc.pdb   beta_chain    3  0.432453
#
#                      file_name_x pdb_id_x structure_type_x state_x  \
# 0    3qdg_D-E-C-A-B_tcr_pmhc.pdb     3qdg         tcr_pmhc    holo
# 1    3qdg_D-E-C-A-B_tcr_pmhc.pdb     3qdg         tcr_pmhc    holo
# 2    3qdg_D-E-C-A-B_tcr_pmhc.pdb     3qdg         tcr_pmhc    holo
# 3    3qdg_D-E-C-A-B_tcr_pmhc.pdb     3qdg         tcr_pmhc    holo
# 4    3qdg_D-E-C-A-B_tcr_pmhc.pdb     3qdg         tcr_pmhc    holo
# ..                           ...      ...              ...     ...
# 809             7n1d_A-B_tcr.pdb     7n1d              tcr     apo
# 810             7n1d_A-B_tcr.pdb     7n1d              tcr     apo
# 811             7n1d_A-B_tcr.pdb     7n1d              tcr     apo
# 812             7n1d_A-B_tcr.pdb     7n1d              tcr     apo
# 813             7n1d_A-B_tcr.pdb     7n1d              tcr     apo
#
#                      file_name_y pdb_id_y structure_type_y state_y  \
# 0               3qeu_A-B_tcr.pdb     3qeu              tcr     apo
# 1               3qeu_A-B_tcr.pdb     3qeu              tcr     apo
# 2               3qeu_A-B_tcr.pdb     3qeu              tcr     apo
# 3               3qeu_A-B_tcr.pdb     3qeu              tcr     apo
# 4               3qeu_A-B_tcr.pdb     3qeu              tcr     apo
# ..                           ...      ...              ...     ...
# 809  7rtr_D-E-C-A-B_tcr_pmhc.pdb     7rtr         tcr_pmhc    holo
# 810  7rtr_D-E-C-A-B_tcr_pmhc.pdb     7rtr         tcr_pmhc    holo
# 811  7rtr_D-E-C-A-B_tcr_pmhc.pdb     7rtr         tcr_pmhc    holo
# 812  7rtr_D-E-C-A-B_tcr_pmhc.pdb     7rtr         tcr_pmhc    holo
# 813  7rtr_D-E-C-A-B_tcr_pmhc.pdb     7rtr         tcr_pmhc    holo
#
#                                 cdr_sequences_collated peptide_sequence  \
# 0    DRGSQS-IYSNGD-AVNFGGGKLI-MRHNA-SNTAGT-ASSLSFGTEAF       ELAGIGILTV
# 1    DRGSQS-IYSNGD-AVNFGGGKLI-MRHNA-SNTAGT-ASSLSFGTEAF       ELAGIGILTV
# 2    DRGSQS-IYSNGD-AVNFGGGKLI-MRHNA-SNTAGT-ASSLSFGTEAF       ELAGIGILTV
# 3    DRGSQS-IYSNGD-AVNFGGGKLI-MRHNA-SNTAGT-ASSLSFGTEAF       ELAGIGILTV
# 4    DRGSQS-IYSNGD-AVNFGGGKLI-MRHNA-SNTAGT-ASSLSFGTEAF       ELAGIGILTV
# ..                                                 ...              ...
# 809     DRGSQS-IYSNGD-AVNRDDKII-SEHNR-FQNEAQ-ASSPDIEQY        YLQPRTFLL
# 810     DRGSQS-IYSNGD-AVNRDDKII-SEHNR-FQNEAQ-ASSPDIEQY        YLQPRTFLL
# 811     DRGSQS-IYSNGD-AVNRDDKII-SEHNR-FQNEAQ-ASSPDIEQY        YLQPRTFLL
# 812     DRGSQS-IYSNGD-AVNRDDKII-SEHNR-FQNEAQ-ASSPDIEQY        YLQPRTFLL
# 813     DRGSQS-IYSNGD-AVNRDDKII-SEHNR-FQNEAQ-ASSPDIEQY        YLQPRTFLL
#
#         mhc_slug
# 0    hla_a_02_01
# 1    hla_a_02_01
# 2    hla_a_02_01
# 3    hla_a_02_01
# 4    hla_a_02_01
# ..           ...
# 809  hla_a_02_01
# 810  hla_a_02_01
# 811  hla_a_02_01
# 812  hla_a_02_01
# 813  hla_a_02_01
#
# [814 rows x 17 columns]

# %%
conformational_change_tcr['comparison'] = conformational_change_tcr['state_x'] + '-' + conformational_change_tcr['state_y']
conformational_change_tcr['comparison'] = conformational_change_tcr['comparison'].map(lambda entry: 'apo-holo' if entry == 'holo-apo' else entry)

# %%
conformational_change_tcr['structure_comparison'] = conformational_change_tcr.apply(
    lambda row: '-'.join(sorted([row.structure_x_name, row.structure_y_name])),
    axis='columns',
)
conformational_change_tcr = conformational_change_tcr.drop_duplicates(['structure_comparison',
                                                                       'chain_type',
                                                                       'cdr']).copy()

# %%
conformational_change_tcr
# Out:
#                   complex_id             structure_x_name  \
# 0    3qdg_D-E-C-A-B_tcr_pmhc  3qdg_D-E-C-A-B_tcr_pmhc.pdb
# 1    3qdg_D-E-C-A-B_tcr_pmhc  3qdg_D-E-C-A-B_tcr_pmhc.pdb
# 2    3qdg_D-E-C-A-B_tcr_pmhc  3qdg_D-E-C-A-B_tcr_pmhc.pdb
# 3    3qdg_D-E-C-A-B_tcr_pmhc  3qdg_D-E-C-A-B_tcr_pmhc.pdb
# 4    3qdg_D-E-C-A-B_tcr_pmhc  3qdg_D-E-C-A-B_tcr_pmhc.pdb
# ..                       ...                          ...
# 809  7rtr_D-E-C-A-B_tcr_pmhc             7n1d_A-B_tcr.pdb
# 810  7rtr_D-E-C-A-B_tcr_pmhc             7n1d_A-B_tcr.pdb
# 811  7rtr_D-E-C-A-B_tcr_pmhc             7n1d_A-B_tcr.pdb
# 812  7rtr_D-E-C-A-B_tcr_pmhc             7n1d_A-B_tcr.pdb
# 813  7rtr_D-E-C-A-B_tcr_pmhc             7n1d_A-B_tcr.pdb
#
#                 structure_y_name   chain_type  cdr      rmsd  \
# 0               3qeu_A-B_tcr.pdb  alpha_chain    1  1.932806
# 1               3qeu_A-B_tcr.pdb  alpha_chain    2  1.308598
# 2               3qeu_A-B_tcr.pdb  alpha_chain    3  1.244062
# 3               3qeu_A-B_tcr.pdb   beta_chain    1  0.809066
# 4               3qeu_A-B_tcr.pdb   beta_chain    2  0.688597
# ..                           ...          ...  ...       ...
# 809  7rtr_D-E-C-A-B_tcr_pmhc.pdb  alpha_chain    2  0.810170
# 810  7rtr_D-E-C-A-B_tcr_pmhc.pdb  alpha_chain    3  0.563263
# 811  7rtr_D-E-C-A-B_tcr_pmhc.pdb   beta_chain    1  0.399182
# 812  7rtr_D-E-C-A-B_tcr_pmhc.pdb   beta_chain    2  0.284455
# 813  7rtr_D-E-C-A-B_tcr_pmhc.pdb   beta_chain    3  0.432453
#
#                      file_name_x pdb_id_x structure_type_x state_x  \
# 0    3qdg_D-E-C-A-B_tcr_pmhc.pdb     3qdg         tcr_pmhc    holo
# 1    3qdg_D-E-C-A-B_tcr_pmhc.pdb     3qdg         tcr_pmhc    holo
# 2    3qdg_D-E-C-A-B_tcr_pmhc.pdb     3qdg         tcr_pmhc    holo
# 3    3qdg_D-E-C-A-B_tcr_pmhc.pdb     3qdg         tcr_pmhc    holo
# 4    3qdg_D-E-C-A-B_tcr_pmhc.pdb     3qdg         tcr_pmhc    holo
# ..                           ...      ...              ...     ...
# 809             7n1d_A-B_tcr.pdb     7n1d              tcr     apo
# 810             7n1d_A-B_tcr.pdb     7n1d              tcr     apo
# 811             7n1d_A-B_tcr.pdb     7n1d              tcr     apo
# 812             7n1d_A-B_tcr.pdb     7n1d              tcr     apo
# 813             7n1d_A-B_tcr.pdb     7n1d              tcr     apo
#
#                      file_name_y pdb_id_y structure_type_y state_y  \
# 0               3qeu_A-B_tcr.pdb     3qeu              tcr     apo
# 1               3qeu_A-B_tcr.pdb     3qeu              tcr     apo
# 2               3qeu_A-B_tcr.pdb     3qeu              tcr     apo
# 3               3qeu_A-B_tcr.pdb     3qeu              tcr     apo
# 4               3qeu_A-B_tcr.pdb     3qeu              tcr     apo
# ..                           ...      ...              ...     ...
# 809  7rtr_D-E-C-A-B_tcr_pmhc.pdb     7rtr         tcr_pmhc    holo
# 810  7rtr_D-E-C-A-B_tcr_pmhc.pdb     7rtr         tcr_pmhc    holo
# 811  7rtr_D-E-C-A-B_tcr_pmhc.pdb     7rtr         tcr_pmhc    holo
# 812  7rtr_D-E-C-A-B_tcr_pmhc.pdb     7rtr         tcr_pmhc    holo
# 813  7rtr_D-E-C-A-B_tcr_pmhc.pdb     7rtr         tcr_pmhc    holo
#
#                                 cdr_sequences_collated peptide_sequence  \
# 0    DRGSQS-IYSNGD-AVNFGGGKLI-MRHNA-SNTAGT-ASSLSFGTEAF       ELAGIGILTV
# 1    DRGSQS-IYSNGD-AVNFGGGKLI-MRHNA-SNTAGT-ASSLSFGTEAF       ELAGIGILTV
# 2    DRGSQS-IYSNGD-AVNFGGGKLI-MRHNA-SNTAGT-ASSLSFGTEAF       ELAGIGILTV
# 3    DRGSQS-IYSNGD-AVNFGGGKLI-MRHNA-SNTAGT-ASSLSFGTEAF       ELAGIGILTV
# 4    DRGSQS-IYSNGD-AVNFGGGKLI-MRHNA-SNTAGT-ASSLSFGTEAF       ELAGIGILTV
# ..                                                 ...              ...
# 809     DRGSQS-IYSNGD-AVNRDDKII-SEHNR-FQNEAQ-ASSPDIEQY        YLQPRTFLL
# 810     DRGSQS-IYSNGD-AVNRDDKII-SEHNR-FQNEAQ-ASSPDIEQY        YLQPRTFLL
# 811     DRGSQS-IYSNGD-AVNRDDKII-SEHNR-FQNEAQ-ASSPDIEQY        YLQPRTFLL
# 812     DRGSQS-IYSNGD-AVNRDDKII-SEHNR-FQNEAQ-ASSPDIEQY        YLQPRTFLL
# 813     DRGSQS-IYSNGD-AVNRDDKII-SEHNR-FQNEAQ-ASSPDIEQY        YLQPRTFLL
#
#         mhc_slug comparison                          structure_comparison
# 0    hla_a_02_01   apo-holo  3qdg_D-E-C-A-B_tcr_pmhc.pdb-3qeu_A-B_tcr.pdb
# 1    hla_a_02_01   apo-holo  3qdg_D-E-C-A-B_tcr_pmhc.pdb-3qeu_A-B_tcr.pdb
# 2    hla_a_02_01   apo-holo  3qdg_D-E-C-A-B_tcr_pmhc.pdb-3qeu_A-B_tcr.pdb
# 3    hla_a_02_01   apo-holo  3qdg_D-E-C-A-B_tcr_pmhc.pdb-3qeu_A-B_tcr.pdb
# 4    hla_a_02_01   apo-holo  3qdg_D-E-C-A-B_tcr_pmhc.pdb-3qeu_A-B_tcr.pdb
# ..           ...        ...                                           ...
# 809  hla_a_02_01   apo-holo  7n1d_A-B_tcr.pdb-7rtr_D-E-C-A-B_tcr_pmhc.pdb
# 810  hla_a_02_01   apo-holo  7n1d_A-B_tcr.pdb-7rtr_D-E-C-A-B_tcr_pmhc.pdb
# 811  hla_a_02_01   apo-holo  7n1d_A-B_tcr.pdb-7rtr_D-E-C-A-B_tcr_pmhc.pdb
# 812  hla_a_02_01   apo-holo  7n1d_A-B_tcr.pdb-7rtr_D-E-C-A-B_tcr_pmhc.pdb
# 813  hla_a_02_01   apo-holo  7n1d_A-B_tcr.pdb-7rtr_D-E-C-A-B_tcr_pmhc.pdb
#
# [676 rows x 19 columns]

# %% [markdown]
# ## Loading pMHC Data

# %%
conformational_change_pmhc = pd.read_csv('../data/processed/apo-holo-tcr-pmhc-class-I-comparisons/pmhc_tcr_contact_apo_holo.csv')
conformational_change_pmhc
# Out:
#                    complex_id             structure_x_name  \
# 0     3qdg_D-E-C-A-B_tcr_pmhc          1jf1_C-A-B_pmhc.pdb
# 1     3qdg_D-E-C-A-B_tcr_pmhc          1jf1_C-A-B_pmhc.pdb
# 2     5c0a_D-E-C-A-B_tcr_pmhc  5c0a_D-E-C-A-B_tcr_pmhc.pdb
# 3     5c0a_D-E-C-A-B_tcr_pmhc  5c0a_D-E-C-A-B_tcr_pmhc.pdb
# 4     5c0a_D-E-C-A-B_tcr_pmhc  5c0a_D-E-C-A-B_tcr_pmhc.pdb
# ...                       ...                          ...
# 3311  7rtr_D-E-C-A-B_tcr_pmhc          7p3d_C-A-B_pmhc.pdb
# 3312  7rtr_D-E-C-A-B_tcr_pmhc          7p3d_C-A-B_pmhc.pdb
# 3313  7rtr_D-E-C-A-B_tcr_pmhc          7rtd_C-A-B_pmhc.pdb
# 3314  7rtr_D-E-C-A-B_tcr_pmhc          7rtd_C-A-B_pmhc.pdb
# 3315  7rtr_D-E-C-A-B_tcr_pmhc          7rtd_C-A-B_pmhc.pdb
#
#                  structure_y_name     chain_type  tcr_contact      rmsd
# 0     3qdg_D-E-C-A-B_tcr_pmhc.pdb     mhc_chain1        False  0.630013
# 1     3qdg_D-E-C-A-B_tcr_pmhc.pdb     mhc_chain1         True  0.582077
# 2             5n1y_C-A-B_pmhc.pdb  antigen_chain        False  0.448858
# 3             5n1y_C-A-B_pmhc.pdb     mhc_chain1        False  0.422160
# 4             5n1y_C-A-B_pmhc.pdb     mhc_chain1         True  0.424287
# ...                           ...            ...          ...       ...
# 3311  7rtr_D-E-C-A-B_tcr_pmhc.pdb     mhc_chain1        False  0.497769
# 3312  7rtr_D-E-C-A-B_tcr_pmhc.pdb     mhc_chain1         True  0.458372
# 3313  7rtr_D-E-C-A-B_tcr_pmhc.pdb  antigen_chain        False  0.455078
# 3314  7rtr_D-E-C-A-B_tcr_pmhc.pdb     mhc_chain1        False  0.449558
# 3315  7rtr_D-E-C-A-B_tcr_pmhc.pdb     mhc_chain1         True  0.493225
#
# [3316 rows x 6 columns]

# %%
conformational_change_pmhc = conformational_change_pmhc.merge(
    summary_df[['file_name', 'pdb_id', 'structure_type', 'state']],
    how='left',
    left_on='structure_x_name',
    right_on='file_name',
).merge(
    summary_df[['file_name', 'pdb_id', 'structure_type', 'state']],
    how='left',
    left_on='structure_y_name',
    right_on='file_name',
    suffixes=('_x', '_y')
).merge(
    summary_df[['cdr_sequences_collated', 'peptide_sequence', 'mhc_slug']],
    how='left',
    left_on='complex_id',
    right_index=True,
)

conformational_change_pmhc
# Out:
#                    complex_id             structure_x_name  \
# 0     3qdg_D-E-C-A-B_tcr_pmhc          1jf1_C-A-B_pmhc.pdb
# 1     3qdg_D-E-C-A-B_tcr_pmhc          1jf1_C-A-B_pmhc.pdb
# 2     5c0a_D-E-C-A-B_tcr_pmhc  5c0a_D-E-C-A-B_tcr_pmhc.pdb
# 3     5c0a_D-E-C-A-B_tcr_pmhc  5c0a_D-E-C-A-B_tcr_pmhc.pdb
# 4     5c0a_D-E-C-A-B_tcr_pmhc  5c0a_D-E-C-A-B_tcr_pmhc.pdb
# ...                       ...                          ...
# 3311  7rtr_D-E-C-A-B_tcr_pmhc          7p3d_C-A-B_pmhc.pdb
# 3312  7rtr_D-E-C-A-B_tcr_pmhc          7p3d_C-A-B_pmhc.pdb
# 3313  7rtr_D-E-C-A-B_tcr_pmhc          7rtd_C-A-B_pmhc.pdb
# 3314  7rtr_D-E-C-A-B_tcr_pmhc          7rtd_C-A-B_pmhc.pdb
# 3315  7rtr_D-E-C-A-B_tcr_pmhc          7rtd_C-A-B_pmhc.pdb
#
#                  structure_y_name     chain_type  tcr_contact      rmsd  \
# 0     3qdg_D-E-C-A-B_tcr_pmhc.pdb     mhc_chain1        False  0.630013
# 1     3qdg_D-E-C-A-B_tcr_pmhc.pdb     mhc_chain1         True  0.582077
# 2             5n1y_C-A-B_pmhc.pdb  antigen_chain        False  0.448858
# 3             5n1y_C-A-B_pmhc.pdb     mhc_chain1        False  0.422160
# 4             5n1y_C-A-B_pmhc.pdb     mhc_chain1         True  0.424287
# ...                           ...            ...          ...       ...
# 3311  7rtr_D-E-C-A-B_tcr_pmhc.pdb     mhc_chain1        False  0.497769
# 3312  7rtr_D-E-C-A-B_tcr_pmhc.pdb     mhc_chain1         True  0.458372
# 3313  7rtr_D-E-C-A-B_tcr_pmhc.pdb  antigen_chain        False  0.455078
# 3314  7rtr_D-E-C-A-B_tcr_pmhc.pdb     mhc_chain1        False  0.449558
# 3315  7rtr_D-E-C-A-B_tcr_pmhc.pdb     mhc_chain1         True  0.493225
#
#                       file_name_x pdb_id_x structure_type_x state_x  \
# 0             1jf1_C-A-B_pmhc.pdb     1jf1             pmhc     apo
# 1             1jf1_C-A-B_pmhc.pdb     1jf1             pmhc     apo
# 2     5c0a_D-E-C-A-B_tcr_pmhc.pdb     5c0a         tcr_pmhc    holo
# 3     5c0a_D-E-C-A-B_tcr_pmhc.pdb     5c0a         tcr_pmhc    holo
# 4     5c0a_D-E-C-A-B_tcr_pmhc.pdb     5c0a         tcr_pmhc    holo
# ...                           ...      ...              ...     ...
# 3311          7p3d_C-A-B_pmhc.pdb     7p3d             pmhc     apo
# 3312          7p3d_C-A-B_pmhc.pdb     7p3d             pmhc     apo
# 3313          7rtd_C-A-B_pmhc.pdb     7rtd             pmhc     apo
# 3314          7rtd_C-A-B_pmhc.pdb     7rtd             pmhc     apo
# 3315          7rtd_C-A-B_pmhc.pdb     7rtd             pmhc     apo
#
#                       file_name_y pdb_id_y structure_type_y state_y  \
# 0     3qdg_D-E-C-A-B_tcr_pmhc.pdb     3qdg         tcr_pmhc    holo
# 1     3qdg_D-E-C-A-B_tcr_pmhc.pdb     3qdg         tcr_pmhc    holo
# 2             5n1y_C-A-B_pmhc.pdb     5n1y             pmhc     apo
# 3             5n1y_C-A-B_pmhc.pdb     5n1y             pmhc     apo
# 4             5n1y_C-A-B_pmhc.pdb     5n1y             pmhc     apo
# ...                           ...      ...              ...     ...
# 3311  7rtr_D-E-C-A-B_tcr_pmhc.pdb     7rtr         tcr_pmhc    holo
# 3312  7rtr_D-E-C-A-B_tcr_pmhc.pdb     7rtr         tcr_pmhc    holo
# 3313  7rtr_D-E-C-A-B_tcr_pmhc.pdb     7rtr         tcr_pmhc    holo
# 3314  7rtr_D-E-C-A-B_tcr_pmhc.pdb     7rtr         tcr_pmhc    holo
# 3315  7rtr_D-E-C-A-B_tcr_pmhc.pdb     7rtr         tcr_pmhc    holo
#
#                                  cdr_sequences_collated peptide_sequence  \
# 0     DRGSQS-IYSNGD-AVNFGGGKLI-MRHNA-SNTAGT-ASSLSFGTEAF       ELAGIGILTV
# 1     DRGSQS-IYSNGD-AVNFGGGKLI-MRHNA-SNTAGT-ASSLSFGTEAF       ELAGIGILTV
# 2     NSAFQY-TYSSGN-AMRGDSSYKLI-SGHDY-FNNNVP-ASSLWEK...       MVWGPDPLYV
# 3     NSAFQY-TYSSGN-AMRGDSSYKLI-SGHDY-FNNNVP-ASSLWEK...       MVWGPDPLYV
# 4     NSAFQY-TYSSGN-AMRGDSSYKLI-SGHDY-FNNNVP-ASSLWEK...       MVWGPDPLYV
# ...                                                 ...              ...
# 3311     DRGSQS-IYSNGD-AVNRDDKII-SEHNR-FQNEAQ-ASSPDIEQY        YLQPRTFLL
# 3312     DRGSQS-IYSNGD-AVNRDDKII-SEHNR-FQNEAQ-ASSPDIEQY        YLQPRTFLL
# 3313     DRGSQS-IYSNGD-AVNRDDKII-SEHNR-FQNEAQ-ASSPDIEQY        YLQPRTFLL
# 3314     DRGSQS-IYSNGD-AVNRDDKII-SEHNR-FQNEAQ-ASSPDIEQY        YLQPRTFLL
# 3315     DRGSQS-IYSNGD-AVNRDDKII-SEHNR-FQNEAQ-ASSPDIEQY        YLQPRTFLL
#
#          mhc_slug
# 0     hla_a_02_01
# 1     hla_a_02_01
# 2     hla_a_02_01
# 3     hla_a_02_01
# 4     hla_a_02_01
# ...           ...
# 3311  hla_a_02_01
# 3312  hla_a_02_01
# 3313  hla_a_02_01
# 3314  hla_a_02_01
# 3315  hla_a_02_01
#
# [3316 rows x 17 columns]

# %%
conformational_change_pmhc['comparison'] = conformational_change_pmhc['state_x'] + '-' + conformational_change_pmhc['state_y']
conformational_change_pmhc['comparison'] = conformational_change_pmhc['comparison'].map(lambda entry: 'apo-holo' if entry == 'holo-apo' else entry)

# %%
conformational_change_pmhc['structure_comparison'] = conformational_change_pmhc.apply(
    lambda row: '-'.join(sorted([row.structure_x_name, row.structure_y_name])),
    axis='columns',
)
conformational_change_pmhc = conformational_change_pmhc.drop_duplicates(['structure_comparison',
                                                                         'chain_type',
                                                                         'tcr_contact']).copy()

# %%
def name_domain(chain_type: str, tcr_contact: bool) -> str:
    match chain_type:
        case 'antigen_chain':
            return 'peptide'

        case 'mhc_chain1':
            if tcr_contact:
                return 'mhc_tcr_contact'

            return 'mhc'

conformational_change_pmhc['domain'] = conformational_change_pmhc.apply(lambda row: name_domain(row.chain_type, row.tcr_contact), axis='columns')

# %%
conformational_change_pmhc
# Out:
#                    complex_id             structure_x_name  \
# 0     3qdg_D-E-C-A-B_tcr_pmhc          1jf1_C-A-B_pmhc.pdb
# 1     3qdg_D-E-C-A-B_tcr_pmhc          1jf1_C-A-B_pmhc.pdb
# 2     5c0a_D-E-C-A-B_tcr_pmhc  5c0a_D-E-C-A-B_tcr_pmhc.pdb
# 3     5c0a_D-E-C-A-B_tcr_pmhc  5c0a_D-E-C-A-B_tcr_pmhc.pdb
# 4     5c0a_D-E-C-A-B_tcr_pmhc  5c0a_D-E-C-A-B_tcr_pmhc.pdb
# ...                       ...                          ...
# 3311  7rtr_D-E-C-A-B_tcr_pmhc          7p3d_C-A-B_pmhc.pdb
# 3312  7rtr_D-E-C-A-B_tcr_pmhc          7p3d_C-A-B_pmhc.pdb
# 3313  7rtr_D-E-C-A-B_tcr_pmhc          7rtd_C-A-B_pmhc.pdb
# 3314  7rtr_D-E-C-A-B_tcr_pmhc          7rtd_C-A-B_pmhc.pdb
# 3315  7rtr_D-E-C-A-B_tcr_pmhc          7rtd_C-A-B_pmhc.pdb
#
#                  structure_y_name     chain_type  tcr_contact      rmsd  \
# 0     3qdg_D-E-C-A-B_tcr_pmhc.pdb     mhc_chain1        False  0.630013
# 1     3qdg_D-E-C-A-B_tcr_pmhc.pdb     mhc_chain1         True  0.582077
# 2             5n1y_C-A-B_pmhc.pdb  antigen_chain        False  0.448858
# 3             5n1y_C-A-B_pmhc.pdb     mhc_chain1        False  0.422160
# 4             5n1y_C-A-B_pmhc.pdb     mhc_chain1         True  0.424287
# ...                           ...            ...          ...       ...
# 3311  7rtr_D-E-C-A-B_tcr_pmhc.pdb     mhc_chain1        False  0.497769
# 3312  7rtr_D-E-C-A-B_tcr_pmhc.pdb     mhc_chain1         True  0.458372
# 3313  7rtr_D-E-C-A-B_tcr_pmhc.pdb  antigen_chain        False  0.455078
# 3314  7rtr_D-E-C-A-B_tcr_pmhc.pdb     mhc_chain1        False  0.449558
# 3315  7rtr_D-E-C-A-B_tcr_pmhc.pdb     mhc_chain1         True  0.493225
#
#                       file_name_x pdb_id_x structure_type_x state_x  \
# 0             1jf1_C-A-B_pmhc.pdb     1jf1             pmhc     apo
# 1             1jf1_C-A-B_pmhc.pdb     1jf1             pmhc     apo
# 2     5c0a_D-E-C-A-B_tcr_pmhc.pdb     5c0a         tcr_pmhc    holo
# 3     5c0a_D-E-C-A-B_tcr_pmhc.pdb     5c0a         tcr_pmhc    holo
# 4     5c0a_D-E-C-A-B_tcr_pmhc.pdb     5c0a         tcr_pmhc    holo
# ...                           ...      ...              ...     ...
# 3311          7p3d_C-A-B_pmhc.pdb     7p3d             pmhc     apo
# 3312          7p3d_C-A-B_pmhc.pdb     7p3d             pmhc     apo
# 3313          7rtd_C-A-B_pmhc.pdb     7rtd             pmhc     apo
# 3314          7rtd_C-A-B_pmhc.pdb     7rtd             pmhc     apo
# 3315          7rtd_C-A-B_pmhc.pdb     7rtd             pmhc     apo
#
#                       file_name_y pdb_id_y structure_type_y state_y  \
# 0     3qdg_D-E-C-A-B_tcr_pmhc.pdb     3qdg         tcr_pmhc    holo
# 1     3qdg_D-E-C-A-B_tcr_pmhc.pdb     3qdg         tcr_pmhc    holo
# 2             5n1y_C-A-B_pmhc.pdb     5n1y             pmhc     apo
# 3             5n1y_C-A-B_pmhc.pdb     5n1y             pmhc     apo
# 4             5n1y_C-A-B_pmhc.pdb     5n1y             pmhc     apo
# ...                           ...      ...              ...     ...
# 3311  7rtr_D-E-C-A-B_tcr_pmhc.pdb     7rtr         tcr_pmhc    holo
# 3312  7rtr_D-E-C-A-B_tcr_pmhc.pdb     7rtr         tcr_pmhc    holo
# 3313  7rtr_D-E-C-A-B_tcr_pmhc.pdb     7rtr         tcr_pmhc    holo
# 3314  7rtr_D-E-C-A-B_tcr_pmhc.pdb     7rtr         tcr_pmhc    holo
# 3315  7rtr_D-E-C-A-B_tcr_pmhc.pdb     7rtr         tcr_pmhc    holo
#
#                                  cdr_sequences_collated peptide_sequence  \
# 0     DRGSQS-IYSNGD-AVNFGGGKLI-MRHNA-SNTAGT-ASSLSFGTEAF       ELAGIGILTV
# 1     DRGSQS-IYSNGD-AVNFGGGKLI-MRHNA-SNTAGT-ASSLSFGTEAF       ELAGIGILTV
# 2     NSAFQY-TYSSGN-AMRGDSSYKLI-SGHDY-FNNNVP-ASSLWEK...       MVWGPDPLYV
# 3     NSAFQY-TYSSGN-AMRGDSSYKLI-SGHDY-FNNNVP-ASSLWEK...       MVWGPDPLYV
# 4     NSAFQY-TYSSGN-AMRGDSSYKLI-SGHDY-FNNNVP-ASSLWEK...       MVWGPDPLYV
# ...                                                 ...              ...
# 3311     DRGSQS-IYSNGD-AVNRDDKII-SEHNR-FQNEAQ-ASSPDIEQY        YLQPRTFLL
# 3312     DRGSQS-IYSNGD-AVNRDDKII-SEHNR-FQNEAQ-ASSPDIEQY        YLQPRTFLL
# 3313     DRGSQS-IYSNGD-AVNRDDKII-SEHNR-FQNEAQ-ASSPDIEQY        YLQPRTFLL
# 3314     DRGSQS-IYSNGD-AVNRDDKII-SEHNR-FQNEAQ-ASSPDIEQY        YLQPRTFLL
# 3315     DRGSQS-IYSNGD-AVNRDDKII-SEHNR-FQNEAQ-ASSPDIEQY        YLQPRTFLL
#
#          mhc_slug comparison                             structure_comparison  \
# 0     hla_a_02_01   apo-holo  1jf1_C-A-B_pmhc.pdb-3qdg_D-E-C-A-B_tcr_pmhc.pdb
# 1     hla_a_02_01   apo-holo  1jf1_C-A-B_pmhc.pdb-3qdg_D-E-C-A-B_tcr_pmhc.pdb
# 2     hla_a_02_01   apo-holo  5c0a_D-E-C-A-B_tcr_pmhc.pdb-5n1y_C-A-B_pmhc.pdb
# 3     hla_a_02_01   apo-holo  5c0a_D-E-C-A-B_tcr_pmhc.pdb-5n1y_C-A-B_pmhc.pdb
# 4     hla_a_02_01   apo-holo  5c0a_D-E-C-A-B_tcr_pmhc.pdb-5n1y_C-A-B_pmhc.pdb
# ...           ...        ...                                              ...
# 3311  hla_a_02_01   apo-holo  7p3d_C-A-B_pmhc.pdb-7rtr_D-E-C-A-B_tcr_pmhc.pdb
# 3312  hla_a_02_01   apo-holo  7p3d_C-A-B_pmhc.pdb-7rtr_D-E-C-A-B_tcr_pmhc.pdb
# 3313  hla_a_02_01   apo-holo  7rtd_C-A-B_pmhc.pdb-7rtr_D-E-C-A-B_tcr_pmhc.pdb
# 3314  hla_a_02_01   apo-holo  7rtd_C-A-B_pmhc.pdb-7rtr_D-E-C-A-B_tcr_pmhc.pdb
# 3315  hla_a_02_01   apo-holo  7rtd_C-A-B_pmhc.pdb-7rtr_D-E-C-A-B_tcr_pmhc.pdb
#
#                domain
# 0                 mhc
# 1     mhc_tcr_contact
# 2             peptide
# 3                 mhc
# 4     mhc_tcr_contact
# ...               ...
# 3311              mhc
# 3312  mhc_tcr_contact
# 3313          peptide
# 3314              mhc
# 3315  mhc_tcr_contact
#
# [2179 rows x 20 columns]

# %% [markdown]
# ## Combining datasets (affinity and conformational change)

# %% [markdown]
# ### TCR data

# %%
def get_holo_pdb_id(state_x: str, pdb_id_x: str, state_y: str, pdb_id_y: str) -> str | None:
    if state_x == 'holo':
        return pdb_id_x

    if state_y == 'holo':
        return pdb_id_y

    return None

conformational_change_tcr['holo_pdb_id'] = conformational_change_tcr.apply(lambda row: get_holo_pdb_id(row.state_x, row.pdb_id_x, row.state_y, row.pdb_id_y), axis='columns')

# %%
combined_data_set_tcr = conformational_change_tcr.merge(atlas_with_pdb_wt, how='inner', left_on='holo_pdb_id', right_on='pdb_id')

# %% [markdown]
# ### pMHC data

# %%
def get_holo_pdb_id(state_x: str, pdb_id_x: str, state_y: str, pdb_id_y: str) -> str | None:
    if state_x == 'holo':
        return pdb_id_x

    if state_y == 'holo':
        return pdb_id_y

    return None

conformational_change_pmhc['holo_pdb_id'] = conformational_change_pmhc.apply(lambda row: get_holo_pdb_id(row.state_x, row.pdb_id_x, row.state_y, row.pdb_id_y), axis='columns')

# %%
combined_data_set_pmhc = conformational_change_pmhc.merge(atlas_with_pdb_wt, how='inner', left_on='holo_pdb_id', right_on='pdb_id')

# %% [markdown]
# ## Visualising results

# %% [markdown]
# ### Conformational Change of the TCRs versus affinity

# %%
combined_data_set_norm_tcr = combined_data_set_tcr.groupby(['cdr_sequences_collated', 'chain_type', 'cdr', 'kd'])['rmsd'].mean().reset_index()

# %%
num_tcrs = len(combined_data_set_norm_tcr['cdr_sequences_collated'].unique())

print('There are', num_tcrs, 'TCRs that also have affinity data for there interactions with pMHC molecules')
# Out:
# There are 12 TCRs that also have affinity data for there interactions with pMHC molecules

# %%
g = sns.lmplot(combined_data_set_norm_tcr, x='rmsd', y='kd', row='chain_type', col='cdr', facet_kws=dict(sharex=False))

def annotate(data, **kws):
    r, p = scipy.stats.pearsonr(data['rmsd'], data['kd'])
    ax = plt.gca()
    ax.text(0.4, 0.9, f'$r^2={r**2:.2f}, p={p:.2e}$', fontsize=12, transform=ax.transAxes)

g.map_dataframe(annotate)

plt.show()

# %% [markdown]
# ### Conformational change of pMHC versus affinity

# %%
combined_data_set_norm_pmhc = combined_data_set_pmhc.groupby(['mhc_slug', 'peptide_sequence', 'domain', 'kd'])['rmsd'].mean().reset_index()

# %%
num_pmhcs = len(combined_data_set_norm_pmhc.groupby(['mhc_slug', 'peptide_sequence']))

print('There are', num_pmhcs, 'pMHCs that also have affinity data for there interactions with TCR molecules')
# Out:
# There are 30 pMHCs that also have affinity data for there interactions with TCR molecules

# %%
g = sns.lmplot(combined_data_set_norm_pmhc, x='rmsd', y='kd', col='domain', facet_kws=dict(sharex=False))

def annotate(data, **kws):
    r, p = scipy.stats.pearsonr(data['rmsd'], data['kd'])
    ax = plt.gca()
    ax.text(0.4, 0.9, f'$r^2={r**2:.2f}, p={p:.2e}$', fontsize=12, transform=ax.transAxes)

g.map_dataframe(annotate)

plt.show()

# %% [markdown]
# ## Conclusion
#
# Overall, there seems to be low correlation between the binding affinity of a TCR-pMHC and the amount of conformational change the interface undergoes. Only the CDR-A2, CDR-A3, and CDR-B3 loops had any correlation but even there the correlation was very low (<10%).
